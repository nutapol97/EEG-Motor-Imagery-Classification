# %%
from braindecode.preprocessing import (
    exponential_moving_standardize,
    preprocess,
    Preprocessor)
from numpy import multiply
from braindecode.datasets import MOABBDataset
from braindecode.preprocessing import create_windows_from_events
import torch
from braindecode.util import set_random_seeds

from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split
from braindecode import EEGClassifier
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import pandas as pd
from sklearn.metrics import confusion_matrix
from braindecode.visualization import plot_confusion_matrix

import numpy as np
import matplotlib.pyplot as plt
import mne
import os
import sys
from mne.datasets import eegbci
import glob
from IPython.display import clear_output
import numpy as np
import torch
from torch import nn
import torch.optim as optim

from mne.datasets import eegbci
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from scipy import signal


import torch
import torch.cuda as cuda
import torch.nn as nn
from torch.autograd import Variable
import math
import wandb
import os
import neptune.new.integrations.sklearn as npt_utils
import neptune.new as neptune



os.environ['http_proxy'] = "http://192.41.170.23:3128"
os.environ['https_proxy'] = "http://192.41.170.23:3128"

from braindecode.models import ShallowFBCSPNet, Deep4Net ,HybridNet,EEGInceptionMI,EEGITNet,ATCNet

# %%
def create_dataloader(X, y, batch_size):
    X_tensor = torch.tensor(X).float()
    y_tensor = torch.tensor(y).long()
    dataset_tensor = TensorDataset(X_tensor, y_tensor)
    dl = torch.utils.data.DataLoader(dataset_tensor, batch_size=batch_size, shuffle=True)
    return dl

def early_stopping(train_loss, validation_loss, min_delta, tolerance):
    counter = 0
    if (validation_loss - train_loss) > min_delta:
        counter +=1
        if counter >= tolerance:
          return True

def extrack_dataset(dataset):
    for x, y, window_ind in dataset:
        x_shape = x.shape
        y_shape = len(dataset.get_metadata().target)
        break
    X = np.zeros((y_shape,x_shape[0],x_shape[1]))
    y_=[]
    i=0
    for x, y, window_ind in dataset:
        X[i]=x
        y_.append(y)
        i+=1
    #X2 = X[:, 7:8, :]
    #X3= X[:, 11:12, :]
    #(288, 22, 1125)
    #X = np.concatenate((X2,X3), axis=1)
    print(X.shape)

    #X = X.reshape(y_shape,X.shape[2],X.shape[1])
    return X,np.array(y_).T


def extrack_dataset_2class(dataset):
    for x, y, window_ind in dataset:
        x_shape = x.shape
        y_shape = len(dataset.get_metadata().target)
        break
    X = np.zeros((y_shape,x_shape[0],x_shape[1]))
    y_=[]
    i=0
    for x, y, window_ind in dataset:
        X[i]=x
        y_.append(y)
        i+=1
    y = np.array(y_).T
    X_ = np.zeros((int(y_shape/2) ,x_shape[0],x_shape[1])) #for 2 class
    y_for_2class =[]
    j=0
    for i in range(y.shape[0]):
        if y[i] == 0 or y[i] == 1:
            y_for_2class.append(y[i])
            X_[j]=X[i]
            j +=1
    y_for_2class = np.array(y_for_2class).T
    X_ = X_.reshape(y_for_2class.shape[0],X_.shape[2],X_.shape[1])
    return X_,y_for_2class

def extrack_dataset_2class_cut(dataset):
    for x, y, window_ind in dataset:
        x_shape = x.shape
        y_shape = len(dataset.get_metadata().target)
        break
    X = np.zeros((y_shape,x_shape[0],x_shape[1]))
    y_=[]
    i=0
    for x, y, window_ind in dataset:
        X[i]=x
        y_.append(y)
        i+=1
    y = np.array(y_).T
    X_ = np.zeros((int(y_shape/2) ,x_shape[0],x_shape[1])) #for 2 class
    y_for_2class =[]
    j=0
    for i in range(y.shape[0]):
        if y[i] == 0 or y[i] == 1:
            y_for_2class.append(y[i])
            X_[j]=X[i]
            j +=1
    y_for_2class = np.array(y_for_2class).T
    X_ = X_.reshape(y_for_2class.shape[0],X_.shape[2],X_.shape[1])
    #100, 1, 576, 22
    X_ = X_[:,64:320,:]
    print(X_.shape)
    return X_,y_for_2class


def train(model,gpu_num,train_loader,test_loader,
          weights_name=False,
          optimizer = None,
          criterion = None,
          num_epochs=500,
          vail_loader= None,
          save_weights = False,
          neptune = True,
          lr = None
         ):

    # Train the model


    train_loss = []
    valid_loss = [10,11]
    train_accuracy = []
    valid_accuracy = []

    old_loss = 100
    old_acc = 0
    valid_loss_vail = []


    for epoch in range(num_epochs):
        iter_loss = 0.0
        correct = 0
        iterations = 0

        model.train()

        for i, (items, classes) in enumerate(train_loader):
            items = Variable(items)
            classes = classes.type(torch.LongTensor)
            classes = Variable(classes)

            if cuda.is_available():
                items = items.cuda(gpu_num)
                classes = classes.cuda(gpu_num)

            optimizer.zero_grad()
            outputs = model(items)
            #avg_pedic = torch.mean(outputs, 1, True).float()
            #avg_pedic = avg_pedic.reshape(classes.shape[0])
            #print(avg_pedic.shape)
            #print(classes.shape)
            loss = criterion(outputs, classes)

            iter_loss += loss.item()
            loss.backward()
            optimizer.step()

            metrics = {"train/train_loss": loss}

            #print(loss)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == classes.data).sum()
            iterations += 1

        train_loss.append(iter_loss/iterations)


        train_accuracy.append(( correct.float() / len(train_loader.dataset)))
        train_metrics = {"train/train_loss": iter_loss/iterations,
                       "train/train_accuracy": (100 * correct.float() / len(train_loader.dataset))}



        loss = 0.0
        correct = 0
        iterations = 0

        model.eval()

        for i, (items, classes) in enumerate(test_loader):
            classes = classes.type(torch.LongTensor)
            items = Variable(items)
            classes = Variable(classes)

            if cuda.is_available():
                items = items.cuda(gpu_num)
                classes = classes.cuda(gpu_num)


            outputs = model(items)
            #avg_pedic = torch.mean(outputs, 1, True).float()
            #avg_pedic = avg_pedic.reshape(classes.shape[0])

            loss += criterion(outputs, classes).item()

            _, predicted = torch.max(outputs.data, 1)

            correct += (predicted == classes.data).sum()
            #print("correct : {}".format(classes.data))
            #print("predicted : {}".format(predicted))
            iterations += 1

        valid_loss.append(loss/iterations)
        correct_scalar = np.array([correct.clone().cpu()])[0]
        valid_accuracy.append(correct_scalar / len(test_loader.dataset) )

        test_metrics = {"Test/Test_loss": loss/iterations,
                       "Test/Test_accuracy": correct_scalar / len(test_loader.dataset) }

        if save_weights is True:
            if epoch+1 > 2 and valid_loss[-1] < old_loss and old_acc <= valid_accuracy[-1] :
                    newpath = r'./{}'.format(weights_name)
                    if not os.path.exists(newpath):
                        os.makedirs(newpath)
                    torch.save(model.state_dict(),'./{}/{:.4f}_{}_{:.4f}_{:.4f}'.format(weights_name,valid_loss[-1],weights_name,valid_loss[-1],valid_accuracy[-1]))
                    part_weights = './{}/{:.4f}_{}_{:.4f}_{:.4f}'.format(weights_name,valid_loss[-1],weights_name,valid_loss[-1],valid_accuracy[-1])
                    old_loss = valid_loss[-1]
                    old_acc = valid_accuracy[-1]

        print ('Epoch %d/%d, Tr Loss: %.4f, Tr Acc: %.4f, Val Loss: %.4f, Val Acc: %.4f , le : %f'
                       %(epoch+1, num_epochs, train_loss[-1], train_accuracy[-1], valid_loss[-1], valid_accuracy[-1],lr))
        if early_stopping(train_loss[-1], valid_loss[-1], min_delta=10, tolerance = 20):
            print("We are at epoch:", epoch+1)
            run[f"epoch/valid_accuracy"].append(valid_accuracy[-1])
            run[f"epoch/train_accuracy"].append(train_accuracy[-1])
            run[f"epoch/train_loss"].append(train_loss[-1])
            run[f"epoch/valid_loss"].append(valid_loss[-1])

            break
        if neptune is True:
            run[f"epoch/valid_accuracy"].append(valid_accuracy[-1])
            run[f"epoch/train_accuracy"].append(train_accuracy[-1])
            run[f"epoch/train_loss"].append(train_loss[-1])
            run[f"epoch/valid_loss"].append(valid_loss[-1])
        if epoch+1 == 1:
            stop_loss = valid_loss[-1]

        if  (epoch+1)//500 == 0 and epoch+1 > 1400 :
            if valid_loss[-1] > valid_loss[-500]:
                print("Stop")
                break

    return train_loss,valid_loss,train_accuracy,valid_accuracy,part_weights
def eval(model,
         gpu_num,
          valid_loader= None,
         labels=None,

         ):
    model.eval()
    y_pred = []
    y_true = []
    correct=0
    evaluate_accuracy= []
    for i, (items, classes) in enumerate(valid_loader):
        classes = classes.type(torch.LongTensor)
        items = Variable(items)
        classes = Variable(classes)
        if cuda.is_available():
            items = items.cuda(gpu_num)
            classes = classes.cuda(gpu_num)

        outputs = model(items)
        _, predicted = torch.max(outputs.data, 1)
        y_pred.append(predicted.clone().cpu().numpy())
        y_true.append(classes.data.clone().cpu().numpy())
        correct += (predicted == classes.data).sum()
    correct_scalar = np.array([correct.clone().cpu()])[0]
    evaluate_accuracy.append(correct_scalar / classes.shape[0] )

    confusion_mat = confusion_matrix(np.array(y_true).T,np.array(y_pred).T )
    left_eva_acc = confusion_mat[0][0]
    right_eva_acc = confusion_mat[1][1]
    foot_eva_acc = confusion_mat[2][2]
    tongue_eva_acc = confusion_mat[3][3]

    run[f"left_eva_acc"].append(left_eva_acc/72)
    run[f"right_eva_acc"].append(right_eva_acc/72)
    run[f"foot_eva_acc"].append(foot_eva_acc/72)
    run[f"tongue_eva_acc"].append(tongue_eva_acc/72)


    run[f"epoch/eval_ACC"].append(evaluate_accuracy[-1])
    run["confusion matrices subject_id : {0}".format(subject_id)].upload(plot_confusion_matrix(confusion_mat, class_names=labels,rotate_row_labels=0,rotate_col_labels=90,with_f1_score=True))
    plot_confusion_matrix(confusion_mat, class_names=labels,rotate_row_labels=0,rotate_col_labels=90,with_f1_score=True).savefig('confusion_matrix/confusion matrices subject_id : {2}_{0}_of_{1}.png'.format(subject_id,params['Datasets'],network))
    return y_pred,y_true,correct_scalar,evaluate_accuracy

# %%
import numpy as np
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim

class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.T = 1125

        # Layer 1
        self.conv1 = nn.Conv2d(1, 16, (1, 22), padding = 0)
        self.batchnorm1 = nn.BatchNorm2d(16, False)

        # Layer 2
        self.padding1 = nn.ZeroPad2d((16, 17, 0, 1))
        self.conv2 = nn.Conv2d(1, 4, (2, 32))
        self.batchnorm2 = nn.BatchNorm2d(4, False)
        self.pooling2 = nn.MaxPool2d(2, 4)

        # Layer 3
        self.padding2 = nn.ZeroPad2d((2, 1, 4, 3))
        self.conv3 = nn.Conv2d(4, 4, (8, 4))
        self.batchnorm3 = nn.BatchNorm2d(4, False)
        self.pooling3 = nn.MaxPool2d((2, 4))

        # FC Layer
        # NOTE: This dimension will depend on the number of timestamps per sample in your data.
        # I have 120 timepoints.
        self.fc1 = nn.Linear(560, 4)


    def forward(self, x):
        # Layer 1
        x = F.elu(self.conv1(x))
        x = self.batchnorm1(x)
        x = F.dropout(x, 0.25)
        x = x.permute(0, 3, 1, 2)

        # Layer 2
        x = self.padding1(x)
        x = F.elu(self.conv2(x))
        x = self.batchnorm2(x)
        x = F.dropout(x, 0.25)
        x = self.pooling2(x)

        # Layer 3
        x = self.padding2(x)
        x = F.elu(self.conv3(x))
        x = self.batchnorm3(x)
        x = F.dropout(x, 0.25)
        x = self.pooling3(x)

        # FC Layer
        x = x.reshape(x.size(0), -1)
        x = F.sigmoid(self.fc1(x))
        return x

# %%
subjects = list(range(6,10))

low_cut_hz = 8.  # low cut frequency for filtering
high_cut_hz = 35.  # high cut frequency for filtering
resample = 128
# Parameters for exponential moving standardization
factor_new = 1e-3
init_block_size = 1000
# Factor to convert from V to uV
factor = 1e6
preprocessors = [
                    Preprocessor('pick_types', eeg=True, meg=False, stim=False),  # Keep EEG sensors
                    Preprocessor(lambda data: multiply(data, factor)),  # Convert from V to uV
                    Preprocessor('filter', l_freq=low_cut_hz, h_freq=high_cut_hz),
                    #Preprocessor('resample', sfreq=resample),
                    Preprocessor(exponential_moving_standardize,  # Exponential movin standardization
                                factor_new=factor_new,
                                 init_block_size=init_block_size)
                    ]
n_epochs = 3000
lr = 0.0001

weight_decay = 0.5 * 0.0001
task_list = ['left', 'right', 'foot', 'tongue']
#task_list = ['foot']
network_list = ['ATCNet','EEGITNet','ShallowFBCSPNet',"EEGnet",'Deep4Net']

#network_list = ['Deep4Net']
#percent_list = [72]
percent_list = [18,36,54,72]
gpu_num = 0
# Out:
# /home/nutapolt/.local/lib/python3.8/site-packages/braindecode/preprocessing/preprocess.py:55: UserWarning: Preprocessing choices with lambda functions cannot be saved.
#   warn('Preprocessing choices with lambda functions cannot be saved.')

# %%
for subject_id in subjects:
    for network in network_list:



        for percent in percent_list:
            run = neptune.init_run(
    project="AitBrainLab/Synthetic",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiJhMTMyMzg0My02NzlhLTQ3N2ItYTdmMS0yNTcwNDBmM2QwM2QifQ==",
)

            #torch.manual_seed(3407)
            dataset = MOABBDataset(dataset_name="BNCI2014001", subject_ids= [subject_id])
            preprocess(dataset, preprocessors)
            trial_start_offset_seconds = -0.5
            # Extract sampling frequency, check that they are same in all datasets
            sfreq = dataset.datasets[0].raw.info['sfreq']
            print(sfreq)
            assert all([ds.raw.info['sfreq'] == sfreq for ds in dataset.datasets])
            # Calculate the trial start offset in samples.
            trial_start_offset_samples = int(trial_start_offset_seconds * sfreq)

            # Create windows using braindecode function for this. It needs parameters to define how
            # trials should be used.
            windows_dataset = create_windows_from_events(
                dataset,
                trial_start_offset_samples=trial_start_offset_samples,
                trial_stop_offset_samples=0,
                preload=True,
            )
            splitted = windows_dataset.split('session')
            train_set = splitted['session_T']
            valid_set = splitted['session_E']

            input_window_samples = train_set[0][0].shape[1]
            X_train,y_train = extrack_dataset(train_set)
            #X_train = X_train[:, np.newaxis,:,:]

            X_valid,y_valid = extrack_dataset(valid_set)
            #

            X_syntheic = np.load("Synthetic_data_V2/X_subject_{0}_72_['left', 'right', 'foot', 'tongue'].npy".format(subject_id)) #np.load("Synthetic_data/X_subject_3_20_[0, 1].npy")#
            y_syntheic = np.load("Synthetic_data_V2/y_subject_{0}_72_['left', 'right', 'foot', 'tongue'].npy".format(subject_id))#np.load("Synthetic_data/y_subject_3_20_[0, 1].npy")#
            #['left', 'right', 'foot', 'tongue']
            if len(task_list) == 4:
                for task in task_list :
                    if task == "left":
                        X1 = X_syntheic[np.random.randint(0,72,percent)]
                        y1 = y_syntheic[np.random.randint(0,72,percent)]
                    if task == "right":
                        X2 = X_syntheic[np.random.randint(72,144,percent)]
                        y2 = y_syntheic[np.random.randint(72,144,percent)]
                    if task == "foot":
                        X3 = X_syntheic[np.random.randint(144,216,percent)]
                        y3 = y_syntheic[np.random.randint(144,216,percent)]
                    if task == "tongue":
                        X4 = X_syntheic[np.random.randint(216,288,percent)]
                        y4 = y_syntheic[np.random.randint(216,288,percent)]
                X_syntheic = np.concatenate((X1,X2,X3,X4),axis=0)
                y_syntheic = np.concatenate((y1,y2,y3,y4),axis=0)

            if len(task_list)==1:
                for task in task_list :
                    if task == "left":
                        X_syntheic = X_syntheic[np.random.randint(0,72,percent)]
                        y_syntheic = y_syntheic[np.random.randint(0,72,percent)]
                    if task == "right":
                        X_syntheic = X_syntheic[np.random.randint(72,144,percent)]
                        y_syntheic = y_syntheic[np.random.randint(72,144,percent)]
                    if task == "foot":
                        X_syntheic = X_syntheic[np.random.randint(144,216,percent)]
                        y_syntheic = y_syntheic[np.random.randint(144,216,percent)]
                    if task == "tongue":
                        X_syntheic = X_syntheic[np.random.randint(216,288,percent)]
                        y_syntheic = y_syntheic[np.random.randint(216,288,percent)]

            X_train = np.concatenate((X_train,X_syntheic),axis = 0)
            y_train = np.concatenate((y_train, y_syntheic),axis = 0)
            print("Done concatenate")



            if network == "EEGnet":
                X_train = X_train.reshape(y_train.shape[0],X_train.shape[2],X_train.shape[1])
                X_train = X_train[:, np.newaxis,:,:]
                print(X_train.shape)
                X_valid = X_valid.reshape(y_valid.shape[0],X_valid.shape[2],X_valid.shape[1])
                X_valid = X_valid[:, np.newaxis,:,:]
                model = EEGNet()
                print(X_valid.shape)

            X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.3,stratify=y_train)
            label_dict = valid_set.datasets[0].windows.event_id.items()
            labels = list(dict(sorted(list(label_dict), key=lambda kv: kv[1])).keys())
            print('train size',X_train.shape, y_train.shape)
            print('test size',X_test.shape, y_test.shape)

            batch_size = X_train.shape[2]

            train_loader = create_dataloader(X_train, y_train, batch_size=batch_size)
            test_loader = create_dataloader(X_test, y_test, batch_size=batch_size)
            valid_loader = create_dataloader(X_valid, y_valid, batch_size=batch_size)
            n_classes=4
            n_chans = X_train.shape[1]

            #network_list = ['ATCNet', 'ShallowFBCSPNet', 'Deep4Net', 'EEGNetv4']
            if network == 'ATCNet' :
                model = ATCNet(
                                n_chans,
                                n_classes
                                )
            if network == "ShallowFBCSPNet":
                model = ShallowFBCSPNet(
                n_chans,
                n_classes,
                input_window_samples=input_window_samples,
                final_conv_length="auto",
                )
            if network == "EEGITNet":
                model = EEGITNet(
                    n_classes,
                    n_chans,
                    input_window_samples=input_window_samples,
                    )
            if network == "Deep4Net":
                model = Deep4Net(
                    n_chans,
                    n_classes,
                    input_window_samples=input_window_samples,
                    final_conv_length='auto',
                    n_filters_time=25,
                    n_filters_spat=25,
                    filter_time_length=10,
                    pool_time_length=3,
                    pool_time_stride=3,
                    n_filters_2=50,
                    filter_length_2=10,
                    n_filters_3=100,
                    filter_length_3=10,
                    n_filters_4=200,
                    filter_length_4=10,
                    first_pool_mode="max",
                    later_pool_mode="max",
                    drop_prob=0.5,
                    #double_time_convs=False,
                    split_first_layer=True,
                    batch_norm=True,
                    batch_norm_alpha=0.1,
                    stride_before_pool=False
                    )



            params = {"Subject number":subject_id,
                      "learning_rate": lr ,
                      "optimizer": "AdamW" ,
                      "Network": network,
                      "Datasets":"BNCI2014001+Synthetic_data_SmoothTimeMask{0}.".format(percent),
                      "sfreq":dataset.datasets[0].raw.info['sfreq'],
                      "Class number":n_classes,
                      "Channel number": train_set[0][0].shape[0],
                      "samples point" : X_train.shape[2]

                      }
            run["parameters"] = params
            net = model.cuda(gpu_num)
            optimizer = optim.Adam(net.parameters(), lr=lr)
            criterion = nn.CrossEntropyLoss()#nn.BCELoss()#
            train_loss,valid_loss,train_accuracy,valid_accuracy,part_weights =train(
                                                                        model = net,
                                                                        gpu_num = gpu_num,
                                                                        train_loader = train_loader,
                                                                        test_loader = test_loader,
                                                                        optimizer = optimizer  ,
                                                                        criterion = criterion,
                                                                        num_epochs=n_epochs,
                                                                        save_weights= True,
                                                                        lr=lr
                                                                             )
            model.load_state_dict(torch.load(part_weights))
            eval(model = net,
                gpu_num = gpu_num,
                valid_loader= valid_loader,
                 labels=labels,
                 )


            run.stop()
# Out:
# https://app.neptune.ai/AitBrainLab/Synthetic/e/SYNTHET-2054
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api/run#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# 250.0
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# (288, 22, 1125)
# (288, 22, 1125)
# Done concatenate
# train size (252, 22, 1125) (252,)
# test size (108, 22, 1125) (108,)
# Epoch 1/3000, Tr Loss: 1.4735, Tr Acc: 0.2460, Val Loss: 1.4116, Val Acc: 0.2407 , le : 0.000100
# Epoch 2/3000, Tr Loss: 1.4629, Tr Acc: 0.2421, Val Loss: 1.4067, Val Acc: 0.2407 , le : 0.000100
# Epoch 3/3000, Tr Loss: 1.4495, Tr Acc: 0.2778, Val Loss: 1.4012, Val Acc: 0.2685 , le : 0.000100
# Epoch 4/3000, Tr Loss: 1.4668, Tr Acc: 0.2262, Val Loss: 1.3980, Val Acc: 0.2500 , le : 0.000100
# Epoch 5/3000, Tr Loss: 1.4977, Tr Acc: 0.2143, Val Loss: 1.3962, Val Acc: 0.2593 , le : 0.000100
# Epoch 6/3000, Tr Loss: 1.4123, Tr Acc: 0.2817, Val Loss: 1.3953, Val Acc: 0.2500 , le : 0.000100
# Epoch 7/3000, Tr Loss: 1.4515, Tr Acc: 0.3056, Val Loss: 1.3949, Val Acc: 0.2222 , le : 0.000100
# Epoch 8/3000, Tr Loss: 1.4823, Tr Acc: 0.2103, Val Loss: 1.3950, Val Acc: 0.1944 , le : 0.000100
# Epoch 9/3000, Tr Loss: 1.4566, Tr Acc: 0.2540, Val Loss: 1.3953, Val Acc: 0.2130 , le : 0.000100
# Epoch 10/3000, Tr Loss: 1.4408, Tr Acc: 0.2619, Val Loss: 1.3956, Val Acc: 0.2222 , le : 0.000100
# Epoch 11/3000, Tr Loss: 1.4141, Tr Acc: 0.2659, Val Loss: 1.3960, Val Acc: 0.2315 , le : 0.000100
# Epoch 12/3000, Tr Loss: 1.4393, Tr Acc: 0.2579, Val Loss: 1.3965, Val Acc: 0.2130 , le : 0.000100
# Epoch 13/3000, Tr Loss: 1.4556, Tr Acc: 0.2778, Val Loss: 1.3972, Val Acc: 0.2130 , le : 0.000100
# Epoch 14/3000, Tr Loss: 1.4773, Tr Acc: 0.2024, Val Loss: 1.3979, Val Acc: 0.2130 , le : 0.000100
# Epoch 15/3000, Tr Loss: 1.4151, Tr Acc: 0.2540, Val Loss: 1.3986, Val Acc: 0.2037 , le : 0.000100
# Epoch 16/3000, Tr Loss: 1.4312, Tr Acc: 0.2540, Val Loss: 1.3993, Val Acc: 0.2130 , le : 0.000100
# Epoch 17/3000, Tr Loss: 1.4609, Tr Acc: 0.2540, Val Loss: 1.4000, Val Acc: 0.2037 , le : 0.000100
# Epoch 18/3000, Tr Loss: 1.4413, Tr Acc: 0.2738, Val Loss: 1.4005, Val Acc: 0.2130 , le : 0.000100
# Epoch 19/3000, Tr Loss: 1.4384, Tr Acc: 0.2698, Val Loss: 1.4012, Val Acc: 0.2222 , le : 0.000100
# Epoch 20/3000, Tr Loss: 1.4412, Tr Acc: 0.2778, Val Loss: 1.4017, Val Acc: 0.2222 , le : 0.000100
# Epoch 21/3000, Tr Loss: 1.4834, Tr Acc: 0.2460, Val Loss: 1.4022, Val Acc: 0.2315 , le : 0.000100
# Epoch 22/3000, Tr Loss: 1.4358, Tr Acc: 0.2540, Val Loss: 1.4027, Val Acc: 0.2315 , le : 0.000100
# Epoch 23/3000, Tr Loss: 1.4342, Tr Acc: 0.2302, Val Loss: 1.4032, Val Acc: 0.2315 , le : 0.000100
# Epoch 24/3000, Tr Loss: 1.4381, Tr Acc: 0.2341, Val Loss: 1.4035, Val Acc: 0.2407 , le : 0.000100
# Epoch 25/3000, Tr Loss: 1.3870, Tr Acc: 0.2857, Val Loss: 1.4040, Val Acc: 0.2500 , le : 0.000100
# Epoch 26/3000, Tr Loss: 1.4511, Tr Acc: 0.2500, Val Loss: 1.4043, Val Acc: 0.2500 , le : 0.000100
# Epoch 27/3000, Tr Loss: 1.3994, Tr Acc: 0.2937, Val Loss: 1.4047, Val Acc: 0.2500 , le : 0.000100
# Epoch 28/3000, Tr Loss: 1.4440, Tr Acc: 0.2500, Val Loss: 1.4049, Val Acc: 0.2407 , le : 0.000100
# Epoch 29/3000, Tr Loss: 1.4226, Tr Acc: 0.2500, Val Loss: 1.4052, Val Acc: 0.2407 , le : 0.000100
# Epoch 30/3000, Tr Loss: 1.4331, Tr Acc: 0.2937, Val Loss: 1.4054, Val Acc: 0.2593 , le : 0.000100
# Epoch 31/3000, Tr Loss: 1.4336, Tr Acc: 0.2659, Val Loss: 1.4055, Val Acc: 0.2593 , le : 0.000100
# Epoch 32/3000, Tr Loss: 1.4142, Tr Acc: 0.2817, Val Loss: 1.4054, Val Acc: 0.2593 , le : 0.000100
# Epoch 33/3000, Tr Loss: 1.4239, Tr Acc: 0.2857, Val Loss: 1.4054, Val Acc: 0.2593 , le : 0.000100
# Epoch 34/3000, Tr Loss: 1.4365, Tr Acc: 0.2579, Val Loss: 1.4054, Val Acc: 0.2593 , le : 0.000100
# Epoch 35/3000, Tr Loss: 1.3853, Tr Acc: 0.3016, Val Loss: 1.4053, Val Acc: 0.2685 , le : 0.000100
# Epoch 36/3000, Tr Loss: 1.3982, Tr Acc: 0.2698, Val Loss: 1.4052, Val Acc: 0.2685 , le : 0.000100
# Epoch 37/3000, Tr Loss: 1.4108, Tr Acc: 0.3294, Val Loss: 1.4052, Val Acc: 0.2870 , le : 0.000100
# Epoch 38/3000, Tr Loss: 1.4058, Tr Acc: 0.2857, Val Loss: 1.4051, Val Acc: 0.2870 , le : 0.000100
# Epoch 39/3000, Tr Loss: 1.4527, Tr Acc: 0.2460, Val Loss: 1.4050, Val Acc: 0.2870 , le : 0.000100
# Epoch 40/3000, Tr Loss: 1.3893, Tr Acc: 0.3095, Val Loss: 1.4049, Val Acc: 0.2963 , le : 0.000100
# Epoch 41/3000, Tr Loss: 1.4006, Tr Acc: 0.2778, Val Loss: 1.4048, Val Acc: 0.2963 , le : 0.000100
# Epoch 42/3000, Tr Loss: 1.3951, Tr Acc: 0.3056, Val Loss: 1.4047, Val Acc: 0.2963 , le : 0.000100
# Epoch 43/3000, Tr Loss: 1.4446, Tr Acc: 0.2460, Val Loss: 1.4049, Val Acc: 0.3148 , le : 0.000100
# Epoch 44/3000, Tr Loss: 1.4326, Tr Acc: 0.2778, Val Loss: 1.4050, Val Acc: 0.3148 , le : 0.000100
# Epoch 45/3000, Tr Loss: 1.4136, Tr Acc: 0.2659, Val Loss: 1.4049, Val Acc: 0.3056 , le : 0.000100
# Epoch 46/3000, Tr Loss: 1.3939, Tr Acc: 0.2817, Val Loss: 1.4048, Val Acc: 0.3056 , le : 0.000100
# Epoch 47/3000, Tr Loss: 1.4153, Tr Acc: 0.2778, Val Loss: 1.4046, Val Acc: 0.3056 , le : 0.000100
# Epoch 48/3000, Tr Loss: 1.3937, Tr Acc: 0.3532, Val Loss: 1.4046, Val Acc: 0.3148 , le : 0.000100
# Epoch 49/3000, Tr Loss: 1.4275, Tr Acc: 0.2341, Val Loss: 1.4047, Val Acc: 0.3148 , le : 0.000100
# Epoch 50/3000, Tr Loss: 1.3797, Tr Acc: 0.3214, Val Loss: 1.4048, Val Acc: 0.3148 , le : 0.000100
# Epoch 51/3000, Tr Loss: 1.4010, Tr Acc: 0.3135, Val Loss: 1.4049, Val Acc: 0.3148 , le : 0.000100
# Epoch 52/3000, Tr Loss: 1.4484, Tr Acc: 0.2659, Val Loss: 1.4049, Val Acc: 0.3148 , le : 0.000100
# Epoch 53/3000, Tr Loss: 1.4276, Tr Acc: 0.2500, Val Loss: 1.4049, Val Acc: 0.3333 , le : 0.000100
# Epoch 54/3000, Tr Loss: 1.3888, Tr Acc: 0.3254, Val Loss: 1.4048, Val Acc: 0.3426 , le : 0.000100
# Epoch 55/3000, Tr Loss: 1.3768, Tr Acc: 0.3254, Val Loss: 1.4049, Val Acc: 0.3426 , le : 0.000100
# Epoch 56/3000, Tr Loss: 1.3730, Tr Acc: 0.3095, Val Loss: 1.4049, Val Acc: 0.3333 , le : 0.000100
# Epoch 57/3000, Tr Loss: 1.3751, Tr Acc: 0.3214, Val Loss: 1.4049, Val Acc: 0.3426 , le : 0.000100
# Epoch 58/3000, Tr Loss: 1.3506, Tr Acc: 0.3413, Val Loss: 1.4050, Val Acc: 0.3333 , le : 0.000100
# Epoch 59/3000, Tr Loss: 1.4039, Tr Acc: 0.2937, Val Loss: 1.4050, Val Acc: 0.3426 , le : 0.000100
# Epoch 60/3000, Tr Loss: 1.3953, Tr Acc: 0.3175, Val Loss: 1.4049, Val Acc: 0.3426 , le : 0.000100
# Epoch 61/3000, Tr Loss: 1.3927, Tr Acc: 0.2817, Val Loss: 1.4049, Val Acc: 0.3241 , le : 0.000100
# Epoch 62/3000, Tr Loss: 1.4177, Tr Acc: 0.2500, Val Loss: 1.4048, Val Acc: 0.3426 , le : 0.000100
# Epoch 63/3000, Tr Loss: 1.4078, Tr Acc: 0.2857, Val Loss: 1.4047, Val Acc: 0.3426 , le : 0.000100
# Epoch 64/3000, Tr Loss: 1.4034, Tr Acc: 0.3254, Val Loss: 1.4048, Val Acc: 0.3333 , le : 0.000100
# Epoch 65/3000, Tr Loss: 1.3989, Tr Acc: 0.3135, Val Loss: 1.4048, Val Acc: 0.3333 , le : 0.000100
# Epoch 66/3000, Tr Loss: 1.3822, Tr Acc: 0.3095, Val Loss: 1.4048, Val Acc: 0.3333 , le : 0.000100
# Epoch 67/3000, Tr Loss: 1.3965, Tr Acc: 0.3452, Val Loss: 1.4044, Val Acc: 0.3426 , le : 0.000100
# Epoch 68/3000, Tr Loss: 1.3841, Tr Acc: 0.3095, Val Loss: 1.4043, Val Acc: 0.3426 , le : 0.000100
# Epoch 69/3000, Tr Loss: 1.3867, Tr Acc: 0.3135, Val Loss: 1.4041, Val Acc: 0.3333 , le : 0.000100
# Epoch 70/3000, Tr Loss: 1.4184, Tr Acc: 0.2778, Val Loss: 1.4039, Val Acc: 0.3333 , le : 0.000100
# Epoch 71/3000, Tr Loss: 1.4621, Tr Acc: 0.2579, Val Loss: 1.4036, Val Acc: 0.3333 , le : 0.000100
# Epoch 72/3000, Tr Loss: 1.3801, Tr Acc: 0.3095, Val Loss: 1.4035, Val Acc: 0.3333 , le : 0.000100
# Epoch 73/3000, Tr Loss: 1.3643, Tr Acc: 0.3730, Val Loss: 1.4034, Val Acc: 0.3333 , le : 0.000100
# Epoch 74/3000, Tr Loss: 1.3883, Tr Acc: 0.3095, Val Loss: 1.4031, Val Acc: 0.3333 , le : 0.000100
# Epoch 75/3000, Tr Loss: 1.3980, Tr Acc: 0.2778, Val Loss: 1.4030, Val Acc: 0.3241 , le : 0.000100
# Epoch 76/3000, Tr Loss: 1.4042, Tr Acc: 0.3254, Val Loss: 1.4028, Val Acc: 0.3148 , le : 0.000100
# Epoch 77/3000, Tr Loss: 1.3734, Tr Acc: 0.3095, Val Loss: 1.4026, Val Acc: 0.3148 , le : 0.000100
# Epoch 78/3000, Tr Loss: 1.3393, Tr Acc: 0.3413, Val Loss: 1.4025, Val Acc: 0.3148 , le : 0.000100
# Epoch 79/3000, Tr Loss: 1.3834, Tr Acc: 0.3254, Val Loss: 1.4024, Val Acc: 0.3148 , le : 0.000100
# Epoch 80/3000, Tr Loss: 1.3830, Tr Acc: 0.3254, Val Loss: 1.4023, Val Acc: 0.3148 , le : 0.000100
# Epoch 81/3000, Tr Loss: 1.4059, Tr Acc: 0.3056, Val Loss: 1.4023, Val Acc: 0.3148 , le : 0.000100
# Epoch 82/3000, Tr Loss: 1.3735, Tr Acc: 0.3294, Val Loss: 1.4021, Val Acc: 0.3148 , le : 0.000100
# Epoch 83/3000, Tr Loss: 1.3489, Tr Acc: 0.3294, Val Loss: 1.4021, Val Acc: 0.3148 , le : 0.000100
# Epoch 84/3000, Tr Loss: 1.3342, Tr Acc: 0.3452, Val Loss: 1.4018, Val Acc: 0.3148 , le : 0.000100
# Epoch 85/3000, Tr Loss: 1.3953, Tr Acc: 0.3056, Val Loss: 1.4017, Val Acc: 0.3148 , le : 0.000100
# Epoch 86/3000, Tr Loss: 1.3031, Tr Acc: 0.4127, Val Loss: 1.4015, Val Acc: 0.3148 , le : 0.000100
# Unexpected error occurred in Neptune background thread: Killing Neptune asynchronous thread. All data is safe on disk and can be later synced manually using `neptune sync` command.
# Exception in thread NeptuneAsyncOpProcessor:
# Traceback (most recent call last):
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 93, in __call__
#     return FinishedApiResponseFuture(future.response())  # wait synchronously
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 200, in response
#     swagger_result = self._get_swagger_result(incoming_response)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 124, in wrapper
#     return func(self, *args, **kwargs)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 300, in _get_swagger_result
#     unmarshal_response(
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 353, in unmarshal_response
#     raise_on_expected(incoming_response)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 420, in raise_on_expected
#     raise make_http_exception(
# bravado.exception.HTTPNotFound: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 226, in run
#     super().run()
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/threading/daemon.py", line 53, in run
#     self.work()
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 242, in work
#     self.process_batch([element.obj for element in batch], batch[-1].ver)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/threading/daemon.py", line 76, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 255, in process_batch
#     processed_count, errors = self._processor._backend.execute_operations(
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 481, in execute_operations
#     self._execute_operations(
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/utils.py", line 127, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 635, in _execute_operations
#     result = self.leaderboard_client.api.executeOperations(**kwargs).response().result
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 95, in __call__
#     self.handle_neptune_http_errors(e.response, exception=e)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in handle_neptune_http_errors
#     raise ObjectNotFound() from exception
# neptune.management.exceptions.ObjectNotFound: Object not found. (code: 22)
# Epoch 87/3000, Tr Loss: 1.3263, Tr Acc: 0.3532, Val Loss: 1.4013, Val Acc: 0.3148 , le : 0.000100
# Epoch 88/3000, Tr Loss: 1.4059, Tr Acc: 0.2659, Val Loss: 1.4011, Val Acc: 0.3148 , le : 0.000100
# Epoch 89/3000, Tr Loss: 1.3630, Tr Acc: 0.2857, Val Loss: 1.4009, Val Acc: 0.3056 , le : 0.000100
# Epoch 90/3000, Tr Loss: 1.3806, Tr Acc: 0.3175, Val Loss: 1.4008, Val Acc: 0.3056 , le : 0.000100
# Epoch 91/3000, Tr Loss: 1.4330, Tr Acc: 0.2460, Val Loss: 1.4006, Val Acc: 0.3056 , le : 0.000100
# Epoch 92/3000, Tr Loss: 1.4006, Tr Acc: 0.3056, Val Loss: 1.4005, Val Acc: 0.3056 , le : 0.000100
# Epoch 93/3000, Tr Loss: 1.3583, Tr Acc: 0.3571, Val Loss: 1.4005, Val Acc: 0.3056 , le : 0.000100
# Epoch 94/3000, Tr Loss: 1.3773, Tr Acc: 0.3452, Val Loss: 1.4005, Val Acc: 0.2963 , le : 0.000100
# Epoch 95/3000, Tr Loss: 1.4187, Tr Acc: 0.2500, Val Loss: 1.4004, Val Acc: 0.2963 , le : 0.000100
# Epoch 96/3000, Tr Loss: 1.3928, Tr Acc: 0.3095, Val Loss: 1.4003, Val Acc: 0.2870 , le : 0.000100
# Epoch 97/3000, Tr Loss: 1.3814, Tr Acc: 0.3175, Val Loss: 1.4001, Val Acc: 0.2870 , le : 0.000100
# Epoch 98/3000, Tr Loss: 1.3621, Tr Acc: 0.3175, Val Loss: 1.3999, Val Acc: 0.2870 , le : 0.000100
# Epoch 99/3000, Tr Loss: 1.3916, Tr Acc: 0.2857, Val Loss: 1.4001, Val Acc: 0.2870 , le : 0.000100
# Epoch 100/3000, Tr Loss: 1.3258, Tr Acc: 0.3254, Val Loss: 1.4001, Val Acc: 0.2870 , le : 0.000100
# Epoch 101/3000, Tr Loss: 1.3683, Tr Acc: 0.2976, Val Loss: 1.4001, Val Acc: 0.2870 , le : 0.000100
# Epoch 102/3000, Tr Loss: 1.4069, Tr Acc: 0.2817, Val Loss: 1.4001, Val Acc: 0.2870 , le : 0.000100
# Epoch 103/3000, Tr Loss: 1.3461, Tr Acc: 0.3056, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 104/3000, Tr Loss: 1.3505, Tr Acc: 0.3294, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 105/3000, Tr Loss: 1.3444, Tr Acc: 0.3571, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 106/3000, Tr Loss: 1.3737, Tr Acc: 0.2976, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 107/3000, Tr Loss: 1.3721, Tr Acc: 0.3135, Val Loss: 1.4001, Val Acc: 0.2963 , le : 0.000100
# Epoch 108/3000, Tr Loss: 1.3813, Tr Acc: 0.2976, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 109/3000, Tr Loss: 1.3474, Tr Acc: 0.3135, Val Loss: 1.4005, Val Acc: 0.2870 , le : 0.000100
# Epoch 110/3000, Tr Loss: 1.3499, Tr Acc: 0.3452, Val Loss: 1.4007, Val Acc: 0.2870 , le : 0.000100
# Epoch 111/3000, Tr Loss: 1.3849, Tr Acc: 0.3095, Val Loss: 1.4008, Val Acc: 0.2870 , le : 0.000100
# Epoch 112/3000, Tr Loss: 1.3445, Tr Acc: 0.3373, Val Loss: 1.4007, Val Acc: 0.2870 , le : 0.000100
# Epoch 113/3000, Tr Loss: 1.3173, Tr Acc: 0.3611, Val Loss: 1.4008, Val Acc: 0.2870 , le : 0.000100
# Epoch 114/3000, Tr Loss: 1.3349, Tr Acc: 0.3492, Val Loss: 1.4008, Val Acc: 0.2870 , le : 0.000100
# Epoch 115/3000, Tr Loss: 1.3579, Tr Acc: 0.3333, Val Loss: 1.4009, Val Acc: 0.2870 , le : 0.000100
# Epoch 116/3000, Tr Loss: 1.3894, Tr Acc: 0.2976, Val Loss: 1.4010, Val Acc: 0.2963 , le : 0.000100
# Epoch 117/3000, Tr Loss: 1.3724, Tr Acc: 0.3214, Val Loss: 1.4009, Val Acc: 0.2963 , le : 0.000100
# Epoch 118/3000, Tr Loss: 1.3675, Tr Acc: 0.3452, Val Loss: 1.4011, Val Acc: 0.2963 , le : 0.000100
# Epoch 119/3000, Tr Loss: 1.3431, Tr Acc: 0.3333, Val Loss: 1.4011, Val Acc: 0.2870 , le : 0.000100
# Epoch 120/3000, Tr Loss: 1.3346, Tr Acc: 0.3294, Val Loss: 1.4010, Val Acc: 0.2963 , le : 0.000100
# Unexpected error occurred in Neptune background thread: Killing Neptune ping thread. Your run's status will not be updated and the run will be shown as inactive.
# Exception in thread NeptunePing:
# Traceback (most recent call last):
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 93, in __call__
#     return FinishedApiResponseFuture(future.response())  # wait synchronously
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 200, in response
#     swagger_result = self._get_swagger_result(incoming_response)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 124, in wrapper
#     return func(self, *args, **kwargs)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 300, in _get_swagger_result
#     unmarshal_response(
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 353, in unmarshal_response
#     raise_on_expected(incoming_response)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/bravado/http_future.py", line 420, in raise_on_expected
#     raise make_http_exception(
# bravado.exception.HTTPNotFound: 404
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/threading/daemon.py", line 53, in run
#     self.work()
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/threading/daemon.py", line 76, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/utils/ping_background_job.py", line 66, in work
#     self._container.ping()
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/metadata_containers/metadata_container.py", line 185, in ping
#     self._backend.ping(self._id, self.container_type)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/utils.py", line 127, in wrapper
#     return func(*args, **kwargs)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 434, in ping
#     self.leaderboard_client.api.ping(
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 95, in __call__
#     self.handle_neptune_http_errors(e.response, exception=e)
#   File "/home/nutapolt/.local/lib/python3.8/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in handle_neptune_http_errors
#     raise ObjectNotFound() from exception
# neptune.management.exceptions.ObjectNotFound: Object not found. (code: 22)
# Epoch 121/3000, Tr Loss: 1.3504, Tr Acc: 0.3571, Val Loss: 1.4010, Val Acc: 0.2963 , le : 0.000100
# Epoch 122/3000, Tr Loss: 1.3467, Tr Acc: 0.3810, Val Loss: 1.4009, Val Acc: 0.2870 , le : 0.000100
# Epoch 123/3000, Tr Loss: 1.3558, Tr Acc: 0.3571, Val Loss: 1.4008, Val Acc: 0.2870 , le : 0.000100
# Epoch 124/3000, Tr Loss: 1.3514, Tr Acc: 0.3135, Val Loss: 1.4009, Val Acc: 0.2870 , le : 0.000100
# Epoch 125/3000, Tr Loss: 1.3724, Tr Acc: 0.3016, Val Loss: 1.4010, Val Acc: 0.2870 , le : 0.000100
# Epoch 126/3000, Tr Loss: 1.3643, Tr Acc: 0.3492, Val Loss: 1.4008, Val Acc: 0.2870 , le : 0.000100
# Epoch 127/3000, Tr Loss: 1.3563, Tr Acc: 0.3056, Val Loss: 1.4008, Val Acc: 0.2870 , le : 0.000100
# Epoch 128/3000, Tr Loss: 1.3555, Tr Acc: 0.3413, Val Loss: 1.4005, Val Acc: 0.2870 , le : 0.000100
# Epoch 129/3000, Tr Loss: 1.3512, Tr Acc: 0.3651, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 130/3000, Tr Loss: 1.3483, Tr Acc: 0.3730, Val Loss: 1.4002, Val Acc: 0.2870 , le : 0.000100
# Epoch 131/3000, Tr Loss: 1.3363, Tr Acc: 0.3492, Val Loss: 1.4002, Val Acc: 0.2963 , le : 0.000100
# Epoch 132/3000, Tr Loss: 1.3742, Tr Acc: 0.2738, Val Loss: 1.4005, Val Acc: 0.2963 , le : 0.000100
# Epoch 133/3000, Tr Loss: 1.3496, Tr Acc: 0.3492, Val Loss: 1.4003, Val Acc: 0.3056 , le : 0.000100
# Epoch 134/3000, Tr Loss: 1.3205, Tr Acc: 0.3611, Val Loss: 1.4005, Val Acc: 0.3056 , le : 0.000100
# Epoch 135/3000, Tr Loss: 1.3250, Tr Acc: 0.3849, Val Loss: 1.4006, Val Acc: 0.2963 , le : 0.000100
# Epoch 136/3000, Tr Loss: 1.3763, Tr Acc: 0.3294, Val Loss: 1.4007, Val Acc: 0.2963 , le : 0.000100
# Epoch 137/3000, Tr Loss: 1.3175, Tr Acc: 0.4048, Val Loss: 1.4007, Val Acc: 0.2963 , le : 0.000100
# Epoch 138/3000, Tr Loss: 1.3580, Tr Acc: 0.3254, Val Loss: 1.4006, Val Acc: 0.2963 , le : 0.000100
# Epoch 139/3000, Tr Loss: 1.3222, Tr Acc: 0.3492, Val Loss: 1.4005, Val Acc: 0.2963 , le : 0.000100
# Epoch 140/3000, Tr Loss: 1.3889, Tr Acc: 0.3214, Val Loss: 1.4004, Val Acc: 0.2963 , le : 0.000100
# Epoch 141/3000, Tr Loss: 1.3340, Tr Acc: 0.3413, Val Loss: 1.4003, Val Acc: 0.2870 , le : 0.000100
# Epoch 142/3000, Tr Loss: 1.3136, Tr Acc: 0.4008, Val Loss: 1.4005, Val Acc: 0.2870 , le : 0.000100
# Epoch 143/3000, Tr Loss: 1.3292, Tr Acc: 0.3611, Val Loss: 1.4005, Val Acc: 0.2778 , le : 0.000100
# Epoch 144/3000, Tr Loss: 1.3284, Tr Acc: 0.3651, Val Loss: 1.4004, Val Acc: 0.2778 , le : 0.000100
# Epoch 145/3000, Tr Loss: 1.3498, Tr Acc: 0.3413, Val Loss: 1.4004, Val Acc: 0.2685 , le : 0.000100
# Epoch 146/3000, Tr Loss: 1.3508, Tr Acc: 0.3571, Val Loss: 1.4004, Val Acc: 0.2778 , le : 0.000100
# Epoch 147/3000, Tr Loss: 1.3469, Tr Acc: 0.3452, Val Loss: 1.4001, Val Acc: 0.2685 , le : 0.000100
# Epoch 148/3000, Tr Loss: 1.3695, Tr Acc: 0.3294, Val Loss: 1.3998, Val Acc: 0.2778 , le : 0.000100
# Epoch 149/3000, Tr Loss: 1.3511, Tr Acc: 0.3571, Val Loss: 1.3997, Val Acc: 0.2870 , le : 0.000100
# Epoch 150/3000, Tr Loss: 1.3595, Tr Acc: 0.3254, Val Loss: 1.3994, Val Acc: 0.2963 , le : 0.000100
# Epoch 151/3000, Tr Loss: 1.3290, Tr Acc: 0.3452, Val Loss: 1.3994, Val Acc: 0.2870 , le : 0.000100
# Epoch 152/3000, Tr Loss: 1.3603, Tr Acc: 0.3095, Val Loss: 1.3993, Val Acc: 0.2963 , le : 0.000100
# Epoch 153/3000, Tr Loss: 1.3108, Tr Acc: 0.3929, Val Loss: 1.3992, Val Acc: 0.2963 , le : 0.000100
# Epoch 154/3000, Tr Loss: 1.3468, Tr Acc: 0.3571, Val Loss: 1.3993, Val Acc: 0.3056 , le : 0.000100
# Epoch 155/3000, Tr Loss: 1.3660, Tr Acc: 0.3333, Val Loss: 1.3992, Val Acc: 0.2963 , le : 0.000100
# Epoch 156/3000, Tr Loss: 1.3227, Tr Acc: 0.3968, Val Loss: 1.3993, Val Acc: 0.2963 , le : 0.000100
# Epoch 157/3000, Tr Loss: 1.3676, Tr Acc: 0.3214, Val Loss: 1.3992, Val Acc: 0.2963 , le : 0.000100
# Epoch 158/3000, Tr Loss: 1.3467, Tr Acc: 0.3095, Val Loss: 1.3993, Val Acc: 0.2963 , le : 0.000100
# Epoch 159/3000, Tr Loss: 1.3258, Tr Acc: 0.3214, Val Loss: 1.3992, Val Acc: 0.2963 , le : 0.000100
# Epoch 160/3000, Tr Loss: 1.3541, Tr Acc: 0.3810, Val Loss: 1.3990, Val Acc: 0.2963 , le : 0.000100
# Epoch 161/3000, Tr Loss: 1.3360, Tr Acc: 0.3571, Val Loss: 1.3992, Val Acc: 0.2963 , le : 0.000100
# Epoch 162/3000, Tr Loss: 1.3139, Tr Acc: 0.3690, Val Loss: 1.3993, Val Acc: 0.2963 , le : 0.000100
# Epoch 163/3000, Tr Loss: 1.3406, Tr Acc: 0.3571, Val Loss: 1.3994, Val Acc: 0.2870 , le : 0.000100
# Epoch 164/3000, Tr Loss: 1.3474, Tr Acc: 0.3810, Val Loss: 1.3993, Val Acc: 0.2963 , le : 0.000100
# Epoch 165/3000, Tr Loss: 1.3241, Tr Acc: 0.3333, Val Loss: 1.3994, Val Acc: 0.2963 , le : 0.000100
# Epoch 166/3000, Tr Loss: 1.2976, Tr Acc: 0.4008, Val Loss: 1.3995, Val Acc: 0.2963 , le : 0.000100
# Epoch 167/3000, Tr Loss: 1.2907, Tr Acc: 0.4325, Val Loss: 1.3998, Val Acc: 0.2963 , le : 0.000100
# Epoch 168/3000, Tr Loss: 1.3244, Tr Acc: 0.3373, Val Loss: 1.3999, Val Acc: 0.2963 , le : 0.000100
# Epoch 169/3000, Tr Loss: 1.3228, Tr Acc: 0.3770, Val Loss: 1.3999, Val Acc: 0.2963 , le : 0.000100
# Epoch 170/3000, Tr Loss: 1.3161, Tr Acc: 0.3611, Val Loss: 1.3999, Val Acc: 0.2963 , le : 0.000100
# Epoch 171/3000, Tr Loss: 1.3452, Tr Acc: 0.3730, Val Loss: 1.4000, Val Acc: 0.2963 , le : 0.000100
# Epoch 172/3000, Tr Loss: 1.3330, Tr Acc: 0.3810, Val Loss: 1.3998, Val Acc: 0.2963 , le : 0.000100
# Epoch 173/3000, Tr Loss: 1.3461, Tr Acc: 0.3611, Val Loss: 1.3999, Val Acc: 0.2963 , le : 0.000100
# Epoch 174/3000, Tr Loss: 1.3149, Tr Acc: 0.3810, Val Loss: 1.3998, Val Acc: 0.2963 , le : 0.000100
# Epoch 175/3000, Tr Loss: 1.3061, Tr Acc: 0.3690, Val Loss: 1.3997, Val Acc: 0.2963 , le : 0.000100
# Epoch 176/3000, Tr Loss: 1.2964, Tr Acc: 0.3968, Val Loss: 1.3993, Val Acc: 0.3148 , le : 0.000100
# Epoch 177/3000, Tr Loss: 1.3044, Tr Acc: 0.4087, Val Loss: 1.3989, Val Acc: 0.3148 , le : 0.000100
# Epoch 178/3000, Tr Loss: 1.3473, Tr Acc: 0.3333, Val Loss: 1.3989, Val Acc: 0.3056 , le : 0.000100
# Epoch 179/3000, Tr Loss: 1.2733, Tr Acc: 0.4127, Val Loss: 1.3992, Val Acc: 0.3056 , le : 0.000100
# Epoch 180/3000, Tr Loss: 1.3472, Tr Acc: 0.3770, Val Loss: 1.3996, Val Acc: 0.2963 , le : 0.000100
# Epoch 181/3000, Tr Loss: 1.3272, Tr Acc: 0.3611, Val Loss: 1.3997, Val Acc: 0.2963 , le : 0.000100
# Epoch 182/3000, Tr Loss: 1.3211, Tr Acc: 0.3571, Val Loss: 1.3998, Val Acc: 0.2963 , le : 0.000100
# Epoch 183/3000, Tr Loss: 1.3116, Tr Acc: 0.3929, Val Loss: 1.3999, Val Acc: 0.2963 , le : 0.000100
# Epoch 184/3000, Tr Loss: 1.3111, Tr Acc: 0.3929, Val Loss: 1.3999, Val Acc: 0.2963 , le : 0.000100
# Epoch 185/3000, Tr Loss: 1.3176, Tr Acc: 0.3849, Val Loss: 1.4001, Val Acc: 0.2870 , le : 0.000100
# Epoch 186/3000, Tr Loss: 1.3485, Tr Acc: 0.3294, Val Loss: 1.4002, Val Acc: 0.2778 , le : 0.000100
# Epoch 187/3000, Tr Loss: 1.3527, Tr Acc: 0.3333, Val Loss: 1.3997, Val Acc: 0.2778 , le : 0.000100
# Epoch 188/3000, Tr Loss: 1.2987, Tr Acc: 0.3810, Val Loss: 1.3997, Val Acc: 0.2778 , le : 0.000100
# Epoch 189/3000, Tr Loss: 1.3043, Tr Acc: 0.3849, Val Loss: 1.3997, Val Acc: 0.2778 , le : 0.000100
# Epoch 190/3000, Tr Loss: 1.3129, Tr Acc: 0.3730, Val Loss: 1.4000, Val Acc: 0.2778 , le : 0.000100
# Epoch 191/3000, Tr Loss: 1.3371, Tr Acc: 0.3373, Val Loss: 1.3999, Val Acc: 0.2778 , le : 0.000100
# Epoch 192/3000, Tr Loss: 1.3168, Tr Acc: 0.3849, Val Loss: 1.3996, Val Acc: 0.2778 , le : 0.000100
# Epoch 193/3000, Tr Loss: 1.2889, Tr Acc: 0.4048, Val Loss: 1.3995, Val Acc: 0.2778 , le : 0.000100
# Epoch 194/3000, Tr Loss: 1.2878, Tr Acc: 0.4167, Val Loss: 1.3994, Val Acc: 0.2778 , le : 0.000100
# Epoch 195/3000, Tr Loss: 1.3158, Tr Acc: 0.3532, Val Loss: 1.3993, Val Acc: 0.2778 , le : 0.000100
# Epoch 196/3000, Tr Loss: 1.3180, Tr Acc: 0.3968, Val Loss: 1.3994, Val Acc: 0.2778 , le : 0.000100
# Epoch 197/3000, Tr Loss: 1.3209, Tr Acc: 0.3571, Val Loss: 1.3993, Val Acc: 0.2778 , le : 0.000100
# Epoch 198/3000, Tr Loss: 1.3346, Tr Acc: 0.3730, Val Loss: 1.3993, Val Acc: 0.2778 , le : 0.000100
# Epoch 199/3000, Tr Loss: 1.3198, Tr Acc: 0.3770, Val Loss: 1.3992, Val Acc: 0.2778 , le : 0.000100
# Epoch 200/3000, Tr Loss: 1.2881, Tr Acc: 0.4286, Val Loss: 1.3989, Val Acc: 0.2778 , le : 0.000100
# Epoch 201/3000, Tr Loss: 1.3099, Tr Acc: 0.3571, Val Loss: 1.3986, Val Acc: 0.2778 , le : 0.000100
# Epoch 202/3000, Tr Loss: 1.2904, Tr Acc: 0.4206, Val Loss: 1.3984, Val Acc: 0.2870 , le : 0.000100
# Epoch 203/3000, Tr Loss: 1.3219, Tr Acc: 0.4048, Val Loss: 1.3979, Val Acc: 0.2685 , le : 0.000100
# Epoch 204/3000, Tr Loss: 1.2921, Tr Acc: 0.4167, Val Loss: 1.3979, Val Acc: 0.2778 , le : 0.000100
# Epoch 205/3000, Tr Loss: 1.3210, Tr Acc: 0.3889, Val Loss: 1.3978, Val Acc: 0.2778 , le : 0.000100
# Epoch 206/3000, Tr Loss: 1.3051, Tr Acc: 0.4127, Val Loss: 1.3977, Val Acc: 0.2685 , le : 0.000100
# Epoch 207/3000, Tr Loss: 1.3064, Tr Acc: 0.3690, Val Loss: 1.3976, Val Acc: 0.2778 , le : 0.000100
# Epoch 208/3000, Tr Loss: 1.3071, Tr Acc: 0.3889, Val Loss: 1.3978, Val Acc: 0.2778 , le : 0.000100
# Epoch 209/3000, Tr Loss: 1.2727, Tr Acc: 0.4167, Val Loss: 1.3977, Val Acc: 0.2778 , le : 0.000100
# Epoch 210/3000, Tr Loss: 1.3052, Tr Acc: 0.3611, Val Loss: 1.3978, Val Acc: 0.2685 , le : 0.000100
# Epoch 211/3000, Tr Loss: 1.3077, Tr Acc: 0.3571, Val Loss: 1.3978, Val Acc: 0.2685 , le : 0.000100
# Epoch 212/3000, Tr Loss: 1.3261, Tr Acc: 0.3294, Val Loss: 1.3980, Val Acc: 0.2685 , le : 0.000100
# Epoch 213/3000, Tr Loss: 1.2938, Tr Acc: 0.3849, Val Loss: 1.3982, Val Acc: 0.2685 , le : 0.000100
# Epoch 214/3000, Tr Loss: 1.3023, Tr Acc: 0.4048, Val Loss: 1.3985, Val Acc: 0.2685 , le : 0.000100
# Epoch 215/3000, Tr Loss: 1.3059, Tr Acc: 0.3889, Val Loss: 1.3988, Val Acc: 0.2685 , le : 0.000100
# Epoch 216/3000, Tr Loss: 1.2549, Tr Acc: 0.4444, Val Loss: 1.3989, Val Acc: 0.2685 , le : 0.000100
# Epoch 217/3000, Tr Loss: 1.2883, Tr Acc: 0.4325, Val Loss: 1.3991, Val Acc: 0.2685 , le : 0.000100
# Epoch 218/3000, Tr Loss: 1.3193, Tr Acc: 0.4246, Val Loss: 1.3991, Val Acc: 0.2685 , le : 0.000100
# Epoch 219/3000, Tr Loss: 1.2883, Tr Acc: 0.4286, Val Loss: 1.3992, Val Acc: 0.2685 , le : 0.000100
# Epoch 220/3000, Tr Loss: 1.2885, Tr Acc: 0.4127, Val Loss: 1.3991, Val Acc: 0.2685 , le : 0.000100
# Epoch 221/3000, Tr Loss: 1.2767, Tr Acc: 0.3968, Val Loss: 1.3991, Val Acc: 0.2685 , le : 0.000100
# Epoch 222/3000, Tr Loss: 1.3322, Tr Acc: 0.3452, Val Loss: 1.3993, Val Acc: 0.2685 , le : 0.000100
# Epoch 223/3000, Tr Loss: 1.2997, Tr Acc: 0.4048, Val Loss: 1.3994, Val Acc: 0.2685 , le : 0.000100
# Epoch 224/3000, Tr Loss: 1.3034, Tr Acc: 0.4008, Val Loss: 1.3999, Val Acc: 0.2685 , le : 0.000100
# Epoch 225/3000, Tr Loss: 1.2863, Tr Acc: 0.3849, Val Loss: 1.3999, Val Acc: 0.2685 , le : 0.000100
# Epoch 226/3000, Tr Loss: 1.2980, Tr Acc: 0.3730, Val Loss: 1.4003, Val Acc: 0.2685 , le : 0.000100
# Epoch 227/3000, Tr Loss: 1.2795, Tr Acc: 0.4206, Val Loss: 1.4004, Val Acc: 0.2685 , le : 0.000100
# Epoch 228/3000, Tr Loss: 1.3095, Tr Acc: 0.3810, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 229/3000, Tr Loss: 1.2811, Tr Acc: 0.4087, Val Loss: 1.4005, Val Acc: 0.2685 , le : 0.000100
# Epoch 230/3000, Tr Loss: 1.3168, Tr Acc: 0.3532, Val Loss: 1.4002, Val Acc: 0.2778 , le : 0.000100
# Epoch 231/3000, Tr Loss: 1.2453, Tr Acc: 0.4206, Val Loss: 1.4006, Val Acc: 0.2778 , le : 0.000100
# Epoch 232/3000, Tr Loss: 1.3094, Tr Acc: 0.3690, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 233/3000, Tr Loss: 1.2627, Tr Acc: 0.4325, Val Loss: 1.4008, Val Acc: 0.2685 , le : 0.000100
# Epoch 234/3000, Tr Loss: 1.2810, Tr Acc: 0.4167, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 235/3000, Tr Loss: 1.2798, Tr Acc: 0.3968, Val Loss: 1.4003, Val Acc: 0.2685 , le : 0.000100
# Epoch 236/3000, Tr Loss: 1.2675, Tr Acc: 0.4246, Val Loss: 1.4003, Val Acc: 0.2685 , le : 0.000100
# Epoch 237/3000, Tr Loss: 1.2609, Tr Acc: 0.4167, Val Loss: 1.4007, Val Acc: 0.2685 , le : 0.000100
# Epoch 238/3000, Tr Loss: 1.2717, Tr Acc: 0.4444, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 239/3000, Tr Loss: 1.2727, Tr Acc: 0.4365, Val Loss: 1.4007, Val Acc: 0.2593 , le : 0.000100
# Epoch 240/3000, Tr Loss: 1.2935, Tr Acc: 0.3889, Val Loss: 1.4007, Val Acc: 0.2685 , le : 0.000100
# Epoch 241/3000, Tr Loss: 1.2971, Tr Acc: 0.3889, Val Loss: 1.4009, Val Acc: 0.2593 , le : 0.000100
# Epoch 242/3000, Tr Loss: 1.2937, Tr Acc: 0.4127, Val Loss: 1.4008, Val Acc: 0.2685 , le : 0.000100
# Epoch 243/3000, Tr Loss: 1.2818, Tr Acc: 0.4127, Val Loss: 1.4005, Val Acc: 0.2685 , le : 0.000100
# Epoch 244/3000, Tr Loss: 1.2812, Tr Acc: 0.3929, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 245/3000, Tr Loss: 1.2671, Tr Acc: 0.4206, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 246/3000, Tr Loss: 1.2723, Tr Acc: 0.4444, Val Loss: 1.4006, Val Acc: 0.2685 , le : 0.000100
# Epoch 247/3000, Tr Loss: 1.2754, Tr Acc: 0.3929, Val Loss: 1.4002, Val Acc: 0.2685 , le : 0.000100
# Epoch 248/3000, Tr Loss: 1.2763, Tr Acc: 0.4246, Val Loss: 1.4003, Val Acc: 0.2685 , le : 0.000100
# Epoch 249/3000, Tr Loss: 1.3128, Tr Acc: 0.3254, Val Loss: 1.4003, Val Acc: 0.2685 , le : 0.000100
# Epoch 250/3000, Tr Loss: 1.2968, Tr Acc: 0.3810, Val Loss: 1.4002, Val Acc: 0.2685 , le : 0.000100
# Epoch 251/3000, Tr Loss: 1.2904, Tr Acc: 0.3968, Val Loss: 1.4004, Val Acc: 0.2685 , le : 0.000100
# Epoch 252/3000, Tr Loss: 1.2711, Tr Acc: 0.4167, Val Loss: 1.4004, Val Acc: 0.2685 , le : 0.000100
# Epoch 253/3000, Tr Loss: 1.2737, Tr Acc: 0.3690, Val Loss: 1.4002, Val Acc: 0.2685 , le : 0.000100
# Epoch 254/3000, Tr Loss: 1.2624, Tr Acc: 0.4563, Val Loss: 1.4001, Val Acc: 0.2685 , le : 0.000100
# Epoch 255/3000, Tr Loss: 1.2532, Tr Acc: 0.4008, Val Loss: 1.4001, Val Acc: 0.2685 , le : 0.000100
# Epoch 256/3000, Tr Loss: 1.2972, Tr Acc: 0.3929, Val Loss: 1.3999, Val Acc: 0.2685 , le : 0.000100
# Epoch 257/3000, Tr Loss: 1.3010, Tr Acc: 0.3651, Val Loss: 1.3998, Val Acc: 0.2593 , le : 0.000100
# Epoch 258/3000, Tr Loss: 1.2618, Tr Acc: 0.4206, Val Loss: 1.3998, Val Acc: 0.2593 , le : 0.000100
# Epoch 259/3000, Tr Loss: 1.2512, Tr Acc: 0.4008, Val Loss: 1.3996, Val Acc: 0.2593 , le : 0.000100
# Epoch 260/3000, Tr Loss: 1.2790, Tr Acc: 0.3968, Val Loss: 1.3996, Val Acc: 0.2593 , le : 0.000100
# Epoch 261/3000, Tr Loss: 1.2686, Tr Acc: 0.4524, Val Loss: 1.3995, Val Acc: 0.2593 , le : 0.000100
# Epoch 262/3000, Tr Loss: 1.2776, Tr Acc: 0.4167, Val Loss: 1.3992, Val Acc: 0.2593 , le : 0.000100
# Epoch 263/3000, Tr Loss: 1.2605, Tr Acc: 0.4484, Val Loss: 1.3992, Val Acc: 0.2593 , le : 0.000100
# Epoch 264/3000, Tr Loss: 1.2633, Tr Acc: 0.4603, Val Loss: 1.3994, Val Acc: 0.2593 , le : 0.000100
# Epoch 265/3000, Tr Loss: 1.2290, Tr Acc: 0.4484, Val Loss: 1.3993, Val Acc: 0.2685 , le : 0.000100
# Epoch 266/3000, Tr Loss: 1.2457, Tr Acc: 0.4683, Val Loss: 1.3993, Val Acc: 0.2593 , le : 0.000100
# Epoch 267/3000, Tr Loss: 1.2493, Tr Acc: 0.4484, Val Loss: 1.3991, Val Acc: 0.2593 , le : 0.000100
# Epoch 268/3000, Tr Loss: 1.2700, Tr Acc: 0.4524, Val Loss: 1.3990, Val Acc: 0.2593 , le : 0.000100
# Epoch 269/3000, Tr Loss: 1.2393, Tr Acc: 0.4127, Val Loss: 1.3990, Val Acc: 0.2685 , le : 0.000100
# Epoch 270/3000, Tr Loss: 1.2996, Tr Acc: 0.3571, Val Loss: 1.3990, Val Acc: 0.2685 , le : 0.000100
# Epoch 271/3000, Tr Loss: 1.2517, Tr Acc: 0.4405, Val Loss: 1.3991, Val Acc: 0.2685 , le : 0.000100
# Epoch 272/3000, Tr Loss: 1.2615, Tr Acc: 0.4365, Val Loss: 1.3993, Val Acc: 0.2685 , le : 0.000100
# Epoch 273/3000, Tr Loss: 1.2531, Tr Acc: 0.4087, Val Loss: 1.3990, Val Acc: 0.2685 , le : 0.000100
# Epoch 274/3000, Tr Loss: 1.2382, Tr Acc: 0.4444, Val Loss: 1.3989, Val Acc: 0.2685 , le : 0.000100
# Epoch 275/3000, Tr Loss: 1.2505, Tr Acc: 0.4524, Val Loss: 1.3992, Val Acc: 0.2685 , le : 0.000100
# Epoch 276/3000, Tr Loss: 1.2789, Tr Acc: 0.4127, Val Loss: 1.3993, Val Acc: 0.2685 , le : 0.000100
# Epoch 277/3000, Tr Loss: 1.2490, Tr Acc: 0.4365, Val Loss: 1.3995, Val Acc: 0.2685 , le : 0.000100
# Epoch 278/3000, Tr Loss: 1.2183, Tr Acc: 0.4206, Val Loss: 1.3998, Val Acc: 0.2593 , le : 0.000100
# Epoch 279/3000, Tr Loss: 1.2546, Tr Acc: 0.4802, Val Loss: 1.3997, Val Acc: 0.2593 , le : 0.000100
# ...
# Epoch 1564/3000, Tr Loss: 0.0095, Tr Acc: 1.0000, Val Loss: 1.8513, Val Acc: 0.3426 , le : 0.000100
# Epoch 1565/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8524, Val Acc: 0.3426 , le : 0.000100
# Epoch 1566/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8528, Val Acc: 0.3426 , le : 0.000100
# Epoch 1567/3000, Tr Loss: 0.0111, Tr Acc: 1.0000, Val Loss: 1.8536, Val Acc: 0.3426 , le : 0.000100
# Epoch 1568/3000, Tr Loss: 0.0099, Tr Acc: 1.0000, Val Loss: 1.8544, Val Acc: 0.3426 , le : 0.000100
# Epoch 1569/3000, Tr Loss: 0.0110, Tr Acc: 1.0000, Val Loss: 1.8547, Val Acc: 0.3426 , le : 0.000100
# Epoch 1570/3000, Tr Loss: 0.0092, Tr Acc: 1.0000, Val Loss: 1.8555, Val Acc: 0.3426 , le : 0.000100
# Epoch 1571/3000, Tr Loss: 0.0157, Tr Acc: 0.9960, Val Loss: 1.8576, Val Acc: 0.3426 , le : 0.000100
# Epoch 1572/3000, Tr Loss: 0.0092, Tr Acc: 1.0000, Val Loss: 1.8592, Val Acc: 0.3333 , le : 0.000100
# Epoch 1573/3000, Tr Loss: 0.0090, Tr Acc: 1.0000, Val Loss: 1.8608, Val Acc: 0.3426 , le : 0.000100
# Epoch 1574/3000, Tr Loss: 0.0103, Tr Acc: 1.0000, Val Loss: 1.8622, Val Acc: 0.3426 , le : 0.000100
# Epoch 1575/3000, Tr Loss: 0.0097, Tr Acc: 1.0000, Val Loss: 1.8636, Val Acc: 0.3426 , le : 0.000100
# Epoch 1576/3000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 1.8643, Val Acc: 0.3426 , le : 0.000100
# Epoch 1577/3000, Tr Loss: 0.0094, Tr Acc: 1.0000, Val Loss: 1.8649, Val Acc: 0.3519 , le : 0.000100
# Epoch 1578/3000, Tr Loss: 0.0097, Tr Acc: 1.0000, Val Loss: 1.8662, Val Acc: 0.3519 , le : 0.000100
# Epoch 1579/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8677, Val Acc: 0.3611 , le : 0.000100
# Epoch 1580/3000, Tr Loss: 0.0061, Tr Acc: 1.0000, Val Loss: 1.8693, Val Acc: 0.3611 , le : 0.000100
# Epoch 1581/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8709, Val Acc: 0.3611 , le : 0.000100
# Epoch 1582/3000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 1.8725, Val Acc: 0.3611 , le : 0.000100
# Epoch 1583/3000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 1.8742, Val Acc: 0.3704 , le : 0.000100
# Epoch 1584/3000, Tr Loss: 0.0097, Tr Acc: 1.0000, Val Loss: 1.8759, Val Acc: 0.3704 , le : 0.000100
# Epoch 1585/3000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 1.8776, Val Acc: 0.3704 , le : 0.000100
# Epoch 1586/3000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 1.8792, Val Acc: 0.3611 , le : 0.000100
# Epoch 1587/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8806, Val Acc: 0.3611 , le : 0.000100
# Epoch 1588/3000, Tr Loss: 0.0093, Tr Acc: 1.0000, Val Loss: 1.8807, Val Acc: 0.3611 , le : 0.000100
# Epoch 1589/3000, Tr Loss: 0.0113, Tr Acc: 1.0000, Val Loss: 1.8811, Val Acc: 0.3519 , le : 0.000100
# Epoch 1590/3000, Tr Loss: 0.0097, Tr Acc: 1.0000, Val Loss: 1.8809, Val Acc: 0.3519 , le : 0.000100
# Epoch 1591/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8804, Val Acc: 0.3611 , le : 0.000100
# Epoch 1592/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8788, Val Acc: 0.3519 , le : 0.000100
# Epoch 1593/3000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 1.8772, Val Acc: 0.3611 , le : 0.000100
# Epoch 1594/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8756, Val Acc: 0.3611 , le : 0.000100
# Epoch 1595/3000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 1.8740, Val Acc: 0.3611 , le : 0.000100
# Epoch 1596/3000, Tr Loss: 0.0100, Tr Acc: 1.0000, Val Loss: 1.8718, Val Acc: 0.3611 , le : 0.000100
# Epoch 1597/3000, Tr Loss: 0.0098, Tr Acc: 1.0000, Val Loss: 1.8702, Val Acc: 0.3611 , le : 0.000100
# Epoch 1598/3000, Tr Loss: 0.0093, Tr Acc: 1.0000, Val Loss: 1.8685, Val Acc: 0.3611 , le : 0.000100
# Epoch 1599/3000, Tr Loss: 0.0157, Tr Acc: 0.9960, Val Loss: 1.8662, Val Acc: 0.3519 , le : 0.000100
# Epoch 1600/3000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 1.8649, Val Acc: 0.3519 , le : 0.000100
# Epoch 1601/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8634, Val Acc: 0.3519 , le : 0.000100
# Epoch 1602/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8626, Val Acc: 0.3519 , le : 0.000100
# Epoch 1603/3000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 1.8622, Val Acc: 0.3519 , le : 0.000100
# Epoch 1604/3000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 1.8620, Val Acc: 0.3519 , le : 0.000100
# Epoch 1605/3000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 1.8619, Val Acc: 0.3704 , le : 0.000100
# Epoch 1606/3000, Tr Loss: 0.0090, Tr Acc: 1.0000, Val Loss: 1.8619, Val Acc: 0.3704 , le : 0.000100
# Epoch 1607/3000, Tr Loss: 0.0089, Tr Acc: 1.0000, Val Loss: 1.8617, Val Acc: 0.3704 , le : 0.000100
# Epoch 1608/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8619, Val Acc: 0.3704 , le : 0.000100
# Epoch 1609/3000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 1.8617, Val Acc: 0.3704 , le : 0.000100
# Epoch 1610/3000, Tr Loss: 0.0090, Tr Acc: 1.0000, Val Loss: 1.8619, Val Acc: 0.3611 , le : 0.000100
# Epoch 1611/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8621, Val Acc: 0.3611 , le : 0.000100
# Epoch 1612/3000, Tr Loss: 0.0095, Tr Acc: 1.0000, Val Loss: 1.8616, Val Acc: 0.3611 , le : 0.000100
# Epoch 1613/3000, Tr Loss: 0.0067, Tr Acc: 1.0000, Val Loss: 1.8614, Val Acc: 0.3611 , le : 0.000100
# Epoch 1614/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8612, Val Acc: 0.3611 , le : 0.000100
# Epoch 1615/3000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 1.8610, Val Acc: 0.3611 , le : 0.000100
# Epoch 1616/3000, Tr Loss: 0.0087, Tr Acc: 1.0000, Val Loss: 1.8608, Val Acc: 0.3611 , le : 0.000100
# Epoch 1617/3000, Tr Loss: 0.0098, Tr Acc: 1.0000, Val Loss: 1.8609, Val Acc: 0.3611 , le : 0.000100
# Epoch 1618/3000, Tr Loss: 0.0113, Tr Acc: 1.0000, Val Loss: 1.8620, Val Acc: 0.3519 , le : 0.000100
# Epoch 1619/3000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 1.8638, Val Acc: 0.3519 , le : 0.000100
# Epoch 1620/3000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 1.8658, Val Acc: 0.3519 , le : 0.000100
# Epoch 1621/3000, Tr Loss: 0.0090, Tr Acc: 1.0000, Val Loss: 1.8686, Val Acc: 0.3519 , le : 0.000100
# Epoch 1622/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8712, Val Acc: 0.3519 , le : 0.000100
# Epoch 1623/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8731, Val Acc: 0.3519 , le : 0.000100
# Epoch 1624/3000, Tr Loss: 0.0102, Tr Acc: 1.0000, Val Loss: 1.8744, Val Acc: 0.3519 , le : 0.000100
# Epoch 1625/3000, Tr Loss: 0.0105, Tr Acc: 1.0000, Val Loss: 1.8752, Val Acc: 0.3519 , le : 0.000100
# Epoch 1626/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8757, Val Acc: 0.3519 , le : 0.000100
# Epoch 1627/3000, Tr Loss: 0.0091, Tr Acc: 1.0000, Val Loss: 1.8754, Val Acc: 0.3519 , le : 0.000100
# Epoch 1628/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8747, Val Acc: 0.3519 , le : 0.000100
# Epoch 1629/3000, Tr Loss: 0.0120, Tr Acc: 1.0000, Val Loss: 1.8754, Val Acc: 0.3519 , le : 0.000100
# Epoch 1630/3000, Tr Loss: 0.0065, Tr Acc: 1.0000, Val Loss: 1.8759, Val Acc: 0.3611 , le : 0.000100
# Epoch 1631/3000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 1.8762, Val Acc: 0.3611 , le : 0.000100
# Epoch 1632/3000, Tr Loss: 0.0104, Tr Acc: 1.0000, Val Loss: 1.8755, Val Acc: 0.3611 , le : 0.000100
# Epoch 1633/3000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 1.8749, Val Acc: 0.3519 , le : 0.000100
# Epoch 1634/3000, Tr Loss: 0.0088, Tr Acc: 1.0000, Val Loss: 1.8747, Val Acc: 0.3519 , le : 0.000100
# Epoch 1635/3000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 1.8751, Val Acc: 0.3519 , le : 0.000100
# Epoch 1636/3000, Tr Loss: 0.0114, Tr Acc: 1.0000, Val Loss: 1.8768, Val Acc: 0.3519 , le : 0.000100
# Epoch 1637/3000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 1.8783, Val Acc: 0.3426 , le : 0.000100
# Epoch 1638/3000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 1.8801, Val Acc: 0.3426 , le : 0.000100
# Epoch 1639/3000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 1.8824, Val Acc: 0.3426 , le : 0.000100
# Epoch 1640/3000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 1.8852, Val Acc: 0.3241 , le : 0.000100
# Epoch 1641/3000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 1.8871, Val Acc: 0.3241 , le : 0.000100
# Epoch 1642/3000, Tr Loss: 0.0090, Tr Acc: 1.0000, Val Loss: 1.8880, Val Acc: 0.3148 , le : 0.000100
# Epoch 1643/3000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 1.8884, Val Acc: 0.3148 , le : 0.000100
# Epoch 1644/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8884, Val Acc: 0.3241 , le : 0.000100
# Epoch 1645/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8878, Val Acc: 0.3241 , le : 0.000100
# Epoch 1646/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8884, Val Acc: 0.3241 , le : 0.000100
# Epoch 1647/3000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 1.8884, Val Acc: 0.3241 , le : 0.000100
# Epoch 1648/3000, Tr Loss: 0.0096, Tr Acc: 1.0000, Val Loss: 1.8868, Val Acc: 0.3241 , le : 0.000100
# Epoch 1649/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8845, Val Acc: 0.3241 , le : 0.000100
# Epoch 1650/3000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 1.8829, Val Acc: 0.3241 , le : 0.000100
# Epoch 1651/3000, Tr Loss: 0.0090, Tr Acc: 1.0000, Val Loss: 1.8806, Val Acc: 0.3241 , le : 0.000100
# Epoch 1652/3000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 1.8782, Val Acc: 0.3241 , le : 0.000100
# Epoch 1653/3000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 1.8760, Val Acc: 0.3333 , le : 0.000100
# Epoch 1654/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8735, Val Acc: 0.3333 , le : 0.000100
# Epoch 1655/3000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 1.8716, Val Acc: 0.3333 , le : 0.000100
# Epoch 1656/3000, Tr Loss: 0.0095, Tr Acc: 1.0000, Val Loss: 1.8695, Val Acc: 0.3333 , le : 0.000100
# Epoch 1657/3000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 1.8672, Val Acc: 0.3426 , le : 0.000100
# Epoch 1658/3000, Tr Loss: 0.0087, Tr Acc: 1.0000, Val Loss: 1.8661, Val Acc: 0.3519 , le : 0.000100
# Epoch 1659/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8656, Val Acc: 0.3519 , le : 0.000100
# Epoch 1660/3000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 1.8656, Val Acc: 0.3519 , le : 0.000100
# Epoch 1661/3000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 1.8648, Val Acc: 0.3519 , le : 0.000100
# Epoch 1662/3000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 1.8644, Val Acc: 0.3519 , le : 0.000100
# Epoch 1663/3000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 1.8654, Val Acc: 0.3519 , le : 0.000100
# Epoch 1664/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8671, Val Acc: 0.3519 , le : 0.000100
# Epoch 1665/3000, Tr Loss: 0.0096, Tr Acc: 1.0000, Val Loss: 1.8688, Val Acc: 0.3519 , le : 0.000100
# Epoch 1666/3000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 1.8697, Val Acc: 0.3519 , le : 0.000100
# Epoch 1667/3000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 1.8708, Val Acc: 0.3519 , le : 0.000100
# Epoch 1668/3000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 1.8718, Val Acc: 0.3333 , le : 0.000100
# Epoch 1669/3000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 1.8724, Val Acc: 0.3241 , le : 0.000100
# Epoch 1670/3000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 1.8728, Val Acc: 0.3241 , le : 0.000100
# Epoch 1671/3000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 1.8719, Val Acc: 0.3241 , le : 0.000100
# Epoch 1672/3000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 1.8706, Val Acc: 0.3241 , le : 0.000100
# Epoch 1673/3000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 1.8692, Val Acc: 0.3241 , le : 0.000100
# Epoch 1674/3000, Tr Loss: 0.0100, Tr Acc: 1.0000, Val Loss: 1.8665, Val Acc: 0.3241 , le : 0.000100
# Epoch 1675/3000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 1.8639, Val Acc: 0.3333 , le : 0.000100
# Epoch 1676/3000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 1.8618, Val Acc: 0.3333 , le : 0.000100
# Epoch 1677/3000, Tr Loss: 0.0089, Tr Acc: 1.0000, Val Loss: 1.8617, Val Acc: 0.3426 , le : 0.000100
# Epoch 1678/3000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 1.8616, Val Acc: 0.3426 , le : 0.000100
# Epoch 1679/3000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 1.8616, Val Acc: 0.3426 , le : 0.000100
# Epoch 1680/3000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 1.8618, Val Acc: 0.3426 , le : 0.000100
# Epoch 1681/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8622, Val Acc: 0.3426 , le : 0.000100
# Epoch 1682/3000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 1.8638, Val Acc: 0.3426 , le : 0.000100
# Epoch 1683/3000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 1.8652, Val Acc: 0.3426 , le : 0.000100
# Epoch 1684/3000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 1.8655, Val Acc: 0.3426 , le : 0.000100
# Epoch 1685/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8658, Val Acc: 0.3426 , le : 0.000100
# Epoch 1686/3000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 1.8667, Val Acc: 0.3426 , le : 0.000100
# Epoch 1687/3000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 1.8675, Val Acc: 0.3426 , le : 0.000100
# Epoch 1688/3000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 1.8681, Val Acc: 0.3426 , le : 0.000100
# Epoch 1689/3000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 1.8687, Val Acc: 0.3426 , le : 0.000100
# Epoch 1690/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8689, Val Acc: 0.3426 , le : 0.000100
# Epoch 1691/3000, Tr Loss: 0.0108, Tr Acc: 0.9960, Val Loss: 1.8728, Val Acc: 0.3426 , le : 0.000100
# Epoch 1692/3000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 1.8762, Val Acc: 0.3426 , le : 0.000100
# Epoch 1693/3000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 1.8792, Val Acc: 0.3333 , le : 0.000100
# Epoch 1694/3000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 1.8814, Val Acc: 0.3333 , le : 0.000100
# Epoch 1695/3000, Tr Loss: 0.0096, Tr Acc: 1.0000, Val Loss: 1.8834, Val Acc: 0.3333 , le : 0.000100
# Epoch 1696/3000, Tr Loss: 0.0058, Tr Acc: 1.0000, Val Loss: 1.8849, Val Acc: 0.3333 , le : 0.000100
# Epoch 1697/3000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 1.8851, Val Acc: 0.3333 , le : 0.000100
# Epoch 1698/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8855, Val Acc: 0.3333 , le : 0.000100
# Epoch 1699/3000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 1.8861, Val Acc: 0.3333 , le : 0.000100
# Epoch 1700/3000, Tr Loss: 0.0064, Tr Acc: 1.0000, Val Loss: 1.8862, Val Acc: 0.3333 , le : 0.000100
# Epoch 1701/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8865, Val Acc: 0.3333 , le : 0.000100
# Epoch 1702/3000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 1.8863, Val Acc: 0.3333 , le : 0.000100
# Epoch 1703/3000, Tr Loss: 0.0093, Tr Acc: 1.0000, Val Loss: 1.8864, Val Acc: 0.3333 , le : 0.000100
# Epoch 1704/3000, Tr Loss: 0.0094, Tr Acc: 1.0000, Val Loss: 1.8851, Val Acc: 0.3333 , le : 0.000100
# Epoch 1705/3000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 1.8843, Val Acc: 0.3333 , le : 0.000100
# Epoch 1706/3000, Tr Loss: 0.0066, Tr Acc: 1.0000, Val Loss: 1.8837, Val Acc: 0.3333 , le : 0.000100
# Epoch 1707/3000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 1.8823, Val Acc: 0.3333 , le : 0.000100
# Epoch 1708/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8820, Val Acc: 0.3426 , le : 0.000100
# Epoch 1709/3000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 1.8809, Val Acc: 0.3426 , le : 0.000100
# Epoch 1710/3000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 1.8808, Val Acc: 0.3426 , le : 0.000100
# Epoch 1711/3000, Tr Loss: 0.0066, Tr Acc: 1.0000, Val Loss: 1.8806, Val Acc: 0.3426 , le : 0.000100
# Epoch 1712/3000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 1.8795, Val Acc: 0.3426 , le : 0.000100
# Epoch 1713/3000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 1.8778, Val Acc: 0.3333 , le : 0.000100
# Epoch 1714/3000, Tr Loss: 0.0064, Tr Acc: 1.0000, Val Loss: 1.8771, Val Acc: 0.3426 , le : 0.000100
# Epoch 1715/3000, Tr Loss: 0.0063, Tr Acc: 1.0000, Val Loss: 1.8753, Val Acc: 0.3426 , le : 0.000100
# Epoch 1716/3000, Tr Loss: 0.0092, Tr Acc: 1.0000, Val Loss: 1.8736, Val Acc: 0.3426 , le : 0.000100
# Epoch 1717/3000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 1.8730, Val Acc: 0.3611 , le : 0.000100
# Epoch 1718/3000, Tr Loss: 0.0093, Tr Acc: 1.0000, Val Loss: 1.8727, Val Acc: 0.3611 , le : 0.000100
# Epoch 1719/3000, Tr Loss: 0.0065, Tr Acc: 1.0000, Val Loss: 1.8727, Val Acc: 0.3611 , le : 0.000100
# Epoch 1720/3000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 1.8733, Val Acc: 0.3611 , le : 0.000100
# Epoch 1721/3000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 1.8738, Val Acc: 0.3611 , le : 0.000100
# Epoch 1722/3000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 1.8746, Val Acc: 0.3611 , le : 0.000100
# Epoch 1723/3000, Tr Loss: 0.0087, Tr Acc: 1.0000, Val Loss: 1.8760, Val Acc: 0.3611 , le : 0.000100
