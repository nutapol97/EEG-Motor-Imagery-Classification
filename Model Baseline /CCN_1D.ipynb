# %%
from braindecode.preprocessing import (
    exponential_moving_standardize, 
    preprocess, 
    Preprocessor)
from numpy import multiply
from braindecode.datasets import MOABBDataset
from braindecode.preprocessing import create_windows_from_events
import torch
from braindecode.util import set_random_seeds

from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split
from braindecode import EEGClassifier
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import pandas as pd
from sklearn.metrics import confusion_matrix
from braindecode.visualization import plot_confusion_matrix

import numpy as np
import matplotlib.pyplot as plt
import mne
import os
import sys
from mne.datasets import eegbci
import glob
from IPython.display import clear_output
import numpy as np
import torch
from torch import nn
import torch.optim as optim

from mne.datasets import eegbci
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from scipy import signal


import torch
import torch.cuda as cuda
import torch.nn as nn
from torch.autograd import Variable
import math
import wandb
import os
import neptune.new.integrations.sklearn as npt_utils
import neptune.new as neptune



os.environ['http_proxy'] = "http://192.41.170.23:3128"
os.environ['https_proxy'] = "http://192.41.170.23:3128"

from braindecode.models import ShallowFBCSPNet, Deep4Net ,EEGNetv4,HybridNet,EEGInceptionMI,EEGITNet

# %%
def create_dataloader(X, y, batch_size):
    X_tensor = torch.tensor(X).float()
    y_tensor = torch.tensor(y).long()
    dataset_tensor = TensorDataset(X_tensor, y_tensor)
    dl = torch.utils.data.DataLoader(dataset_tensor, batch_size=batch_size, shuffle=True)
    return dl

def early_stopping(train_loss, validation_loss, min_delta, tolerance):
    counter = 0
    if (validation_loss - train_loss) > min_delta:
        counter +=1
        if counter >= tolerance:
          return True

def extrack_dataset(dataset):
    for x, y, window_ind in dataset:
        x_shape = x.shape
        y_shape = len(dataset.get_metadata().target)
        break
    X = np.zeros((y_shape,x_shape[0],x_shape[1]))
    y_=[]
    i=0
    for x, y, window_ind in dataset:
        X[i]=x
        y_.append(y)
        i+=1
    return X,np.array(y_).T

def train(model,gpu_num,train_loader,test_loader,
          weights_name=False,
          optimizer = None,
          criterion = None,
          num_epochs=500,
          vail_loader= None,
          save_weights = False,
          neptune = True
         ):

    # Train the model


    train_loss = []
    valid_loss = [10,11]
    train_accuracy = []
    valid_accuracy = []

    old_loss = 100
    old_acc = 0
    valid_loss_vail = []


    for epoch in range(num_epochs):
        iter_loss = 0.0
        correct = 0
        iterations = 0

        model.train()

        for i, (items, classes) in enumerate(train_loader):
            items = Variable(items)
            classes = classes.type(torch.LongTensor)
            classes = Variable(classes)

            if cuda.is_available():
                items = items.cuda(gpu_num)
                classes = classes.cuda(gpu_num)

            optimizer.zero_grad()
            outputs = model(items)
            loss = criterion(outputs, classes)

            iter_loss += loss.item()
            loss.backward()
            optimizer.step()

            metrics = {"train/train_loss": loss}

            #print(loss)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == classes.data).sum()
            iterations += 1

        train_loss.append(iter_loss/iterations)


        train_accuracy.append(( correct.float() / len(train_loader.dataset)))
        train_metrics = {"train/train_loss": iter_loss/iterations,
                       "train/train_accuracy": (100 * correct.float() / len(train_loader.dataset))}



        loss = 0.0
        correct = 0
        iterations = 0
        model.eval()

        for i, (items, classes) in enumerate(test_loader):
            classes = classes.type(torch.LongTensor)
            items = Variable(items)
            classes = Variable(classes)

            if cuda.is_available():
                items = items.cuda(gpu_num)
                classes = classes.cuda(gpu_num)


            outputs = model(items)
            loss += criterion(outputs, classes).item()

            _, predicted = torch.max(outputs.data, 1)

            correct += (predicted == classes.data).sum()
            #print("correct : {}".format(classes.data))
            #print("predicted : {}".format(predicted))
            iterations += 1

        valid_loss.append(loss/iterations)
        correct_scalar = np.array([correct.clone().cpu()])[0]
        valid_accuracy.append(correct_scalar / len(test_loader.dataset) )

        test_metrics = {"Test/Test_loss": loss/iterations,
                       "Test/Test_accuracy": correct_scalar / len(test_loader.dataset) }
        if save_weights is True:
            if epoch+1 > 2 and valid_loss[-1] < old_loss and old_acc <= valid_accuracy[-1] :
                    newpath = r'./{}'.format(weights_name)
                    if not os.path.exists(newpath):
                        os.makedirs(newpath)
                    torch.save(model.state_dict(),               './{}/{:.4f}_{}_{:.4f}_{:.4f}'.format(weights_name,valid_loss[-1],weights_name,valid_loss[-1],valid_accuracy[-1]))
                    old_loss = valid_loss[-1]
                    old_acc = valid_accuracy[-1]

        print ('Epoch %d/%d, Tr Loss: %.4f, Tr Acc: %.4f, Val Loss: %.4f, Val Acc: %.4f'
                       %(epoch+1, num_epochs, train_loss[-1], train_accuracy[-1], valid_loss[-1], valid_accuracy[-1]))
        if early_stopping(train_loss[-1], valid_loss[-1], min_delta=10, tolerance = 20):
            print("We are at epoch:", epoch+1)
            run[f"epoch/valid_accuracy"].append(valid_accuracy[-1])
            run[f"epoch/train_accuracy"].append(train_accuracy[-1])
            run[f"epoch/train_loss"].append(train_loss[-1])
            run[f"epoch/valid_loss"].append(valid_loss[-1])

            break
        if neptune is True:
            run[f"epoch/valid_accuracy"].append(valid_accuracy[-1])
            run[f"epoch/train_accuracy"].append(train_accuracy[-1])
            run[f"epoch/train_loss"].append(train_loss[-1])
            run[f"epoch/valid_loss"].append(valid_loss[-1])


    return train_loss,valid_loss,train_accuracy,valid_accuracy
def eval(model,
         gpu_num,
          vail_loader= None,
         labels=None,
         ):
    model.eval()
    y_pred = []
    y_true = []
    correct=0
    for i, (items, classes) in enumerate(vail_loader):
        classes = classes.type(torch.LongTensor)
        items = Variable(items)
        classes = Variable(classes)
        if cuda.is_available():
            items = items.cuda(gpu_num)
            classes = classes.cuda(gpu_num)

        outputs = model(items)
        _, predicted = torch.max(outputs.data, 1)
        y_pred.append(predicted.clone().cpu().numpy())
        y_true.append(classes.data.clone().cpu().numpy())
        correct += (predicted == classes.data).sum()
    correct_scalar = np.array([correct.clone().cpu()])[0]
    valid_accuracy.append(correct_scalar / len(test_loader.dataset) )

    confusion_mat = confusion_matrix(np.array(y_true).T,np.array(y_pred).T )
    run["confusion matrices subject_id : {0}".format(subject_id)].upload(plot_confusion_matrix(confusion_mat, class_names=labels,rotate_row_labels=0,rotate_col_labels=90,with_f1_score=True))
    return y_pred,y_true,correct_scalar,valid_accuracy

# %%
subjects = list(range(1,10))

low_cut_hz = .5  # low cut frequency for filtering
high_cut_hz = 14.0  # high cut frequency for filtering
# Parameters for exponential moving standardization
#factor_new = 1e-3
#init_block_size = 1000
# Factor to convert from V to uV
factor = 1e6
preprocessors = [
                    Preprocessor('pick_types', eeg=True, meg=False, stim=False),  # Keep EEG sensors
                    Preprocessor(lambda data: multiply(data, factor)),  # Convert from V to uV
                    #Preprocessor('resample', sfreq=128),
                   # Preprocessor("filter", l_freq=low_cut_hz, h_freq=high_cut_hz)
                    ]
n_epochs = 10000
# Out:
# /home/nutapolt/.local/lib/python3.8/site-packages/braindecode/preprocessing/preprocess.py:55: UserWarning: Preprocessing choices with lambda functions cannot be saved.
#   warn('Preprocessing choices with lambda functions cannot be saved.')

# %%
# Convolutional neural network (two convolutional layers)
class ConvNet(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, out_size):
        super().__init__()
        #using sequential helps bind multiple operations together
        self.layer1 = nn.Sequential(
            #padding = (kernel_size - 1) / 2 = 2
            nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=2),
            nn.BatchNorm1d(out_channels),
            nn.ReLU(),
            # nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.layer2 = nn.Sequential(
            nn.Conv1d(out_channels, out_channels*2, kernel_size=kernel_size, stride=1, padding=2),
            nn.BatchNorm1d(out_channels*2),
            nn.ReLU(),
            # nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv1d(out_channels*2, out_channels, kernel_size=kernel_size, stride=1, padding=2),
            nn.BatchNorm1d(out_channels),
            nn.ReLU(),
        )


        self.fc = nn.Linear(linear_shape  , out_size)
        #self.fc = nn.Linear(80064 , 2)

        self.drop_out = nn.Dropout(0.5)

    def forward(self, x):
        out = self.layer1(x)
        out = self.drop_out(out)
        out = self.layer2(out)
        out = self.drop_out(out)
        out = self.layer3(out)
        #out = self.drop_out(out)
        #out = self.layer4(out)
        #out = self.drop_out(out)

        out = out.reshape(out.size(0), -1)   #can also use .view()
        out = self.fc(out)
        return out

# %%
for subject_id in subjects:
    run = neptune.init_run(
    project="nutapol1997/EEG-MI",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiJhMTMyMzg0My02NzlhLTQ3N2ItYTdmMS0yNTcwNDBmM2QwM2QifQ==",
    )


    dataset_name="BNCI2014001"
    dataset = MOABBDataset(dataset_name=dataset_name, subject_ids= [1])
    preprocess(dataset, preprocessors)
    trial_start_offset_seconds = -0.5
    # Extract sampling frequency, check that they are same in all datasets
    sfreq = dataset.datasets[0].raw.info['sfreq']
    print(sfreq)
    assert all([ds.raw.info['sfreq'] == sfreq for ds in dataset.datasets])
    # Calculate the trial start offset in samples.
    trial_start_offset_samples = int(trial_start_offset_seconds * sfreq)

    # Create windows using braindecode function for this. It needs parameters to define how
    # trials should be used.
    windows_dataset = create_windows_from_events(
        dataset,
        trial_start_offset_samples=trial_start_offset_samples,
        trial_stop_offset_samples=0,
        preload=True,
    )
    splitted = windows_dataset.split('session')
    train_set = splitted['session_T']
    valid_set = splitted['session_E']
    n_chans = train_set[0][0].shape[0]
    input_window_samples = train_set[0][0].shape[1]
    X_train,y_train = extrack_dataset(train_set)
    X_valid,y_valid = extrack_dataset(valid_set)
    X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.3,stratify=y_train)
    label_dict = valid_set.datasets[0].windows.event_id.items()
    labels = list(dict(sorted(list(label_dict), key=lambda kv: kv[1])).keys())
    print('train size',X_train.shape, y_train.shape)
    print('test size',X_test.shape, y_test.shape)


    batch_size = X_train.shape[2]

    train_loader = create_dataloader(X_train, y_train, batch_size=batch_size)
    test_loader = create_dataloader(X_test, y_test, batch_size=batch_size)
    valid_loader = create_dataloader(X_valid, y_valid, batch_size=batch_size)
    n_classes=4

    num_step =math.ceil(len(train_loader.dataset) / batch_size)



    in_channels  = n_chans #C3, C4
    out_channels = 64  #five is logical because we have freq= 8, 9, 10, 11, 12 that we want to capture
    out_size     = 4  #left or right
    kernel_size  = 5


    x_train = torch.FloatTensor(X_train)
    fake_eeg_data = torch.randn_like(x_train) #(batch_size, channel, length)
    layer1 = nn.Sequential(
                    #padding = (kernel_size - 1) / 2 = 2
                    nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=2),
                    nn.BatchNorm1d(out_channels),
                    nn.ReLU()
                    # nn.MaxPool2d(kernel_size=2, stride=2)
                )
    layer2 = nn.Sequential(
                    nn.Conv1d(out_channels, out_channels*2, kernel_size=kernel_size, stride=1, padding=2),
                    nn.BatchNorm1d(out_channels*2),
                    nn.ReLU()
                    # nn.MaxPool2d(kernel_size=2, stride=2)
                )
    layer3 = nn.Sequential(
                    nn.Conv1d(out_channels*2, out_channels, kernel_size=kernel_size, stride=1, padding=2),
                    nn.BatchNorm1d(out_channels),
                    nn.ReLU()
                )


    out = layer1(fake_eeg_data)
    out = layer2(out)
    out = layer3(out)
    out = out.reshape(out.size(0), -1)
    linear_shape = out.shape[1]
    fc = nn.Linear(linear_shape, out_size)
    out = fc(out)
    model = ConvNet(in_channels, out_channels, kernel_size, out_size).cuda(0)
    seed = 20200220
    set_random_seeds(seed=seed, cuda=cuda)

    n_classes = 4

    n_chans = train_set[0][0].shape[0]
    input_window_samples = train_set[0][0].shape[1]



    lr = 1 * 0.000001


    params = {"Subject number":subject_id,
              "learning_rate": lr ,
              "optimizer": "AdamW" ,
              "Network":"CNN1D",
              "Datasets":dataset_name,
              "sfreq":dataset.datasets[0].raw.info['sfreq'],
              "Class number":n_classes,
              "Channel number": train_set[0][0].shape[0]
              }
    run["parameters"] = params
    net = model.cuda(0)
    optimizer = optim.Adam(net.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    train_loss,valid_loss,train_accuracy,valid_accuracy =train(
                                                                model = net,
                                                                gpu_num = 0,
                                                                train_loader = train_loader,
                                                                test_loader = test_loader,
                                                                optimizer = optimizer  ,
                                                                criterion = criterion,
                                                                num_epochs=n_epochs
                                                                     )
    eval(model = net,
        gpu_num = 0,
          vail_loader= valid_loader,
         labels=labels,
         )


    run.stop()
# Out:
# https://app.neptune.ai/nutapol1997/EEG-MI/e/EEG-155
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api/run#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 250.0
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# train size (201, 22, 1125) (201,)
# test size (87, 22, 1125) (87,)
# Epoch 1/10000, Tr Loss: 1.4664, Tr Acc: 0.2637, Val Loss: 1.3969, Val Acc: 0.2299
# Epoch 2/10000, Tr Loss: 1.4871, Tr Acc: 0.2587, Val Loss: 1.3952, Val Acc: 0.2414
# Epoch 3/10000, Tr Loss: 1.4737, Tr Acc: 0.2388, Val Loss: 1.3948, Val Acc: 0.2299
# Epoch 4/10000, Tr Loss: 1.4380, Tr Acc: 0.2587, Val Loss: 1.3949, Val Acc: 0.2184
# Epoch 5/10000, Tr Loss: 1.4192, Tr Acc: 0.2886, Val Loss: 1.3953, Val Acc: 0.2184
# Epoch 6/10000, Tr Loss: 1.4367, Tr Acc: 0.2736, Val Loss: 1.3959, Val Acc: 0.2069
# Epoch 7/10000, Tr Loss: 1.4737, Tr Acc: 0.2139, Val Loss: 1.3963, Val Acc: 0.2069
# Epoch 8/10000, Tr Loss: 1.4415, Tr Acc: 0.1990, Val Loss: 1.3967, Val Acc: 0.1954
# Epoch 9/10000, Tr Loss: 1.4601, Tr Acc: 0.2438, Val Loss: 1.3972, Val Acc: 0.1724
# Epoch 10/10000, Tr Loss: 1.4552, Tr Acc: 0.2438, Val Loss: 1.3977, Val Acc: 0.2069
# Epoch 11/10000, Tr Loss: 1.4559, Tr Acc: 0.2736, Val Loss: 1.3980, Val Acc: 0.2069
# Epoch 12/10000, Tr Loss: 1.4620, Tr Acc: 0.2687, Val Loss: 1.3984, Val Acc: 0.2184
# Epoch 13/10000, Tr Loss: 1.4283, Tr Acc: 0.2239, Val Loss: 1.3988, Val Acc: 0.2184
# Epoch 14/10000, Tr Loss: 1.4306, Tr Acc: 0.2637, Val Loss: 1.3992, Val Acc: 0.2184
# Epoch 15/10000, Tr Loss: 1.4402, Tr Acc: 0.2488, Val Loss: 1.3996, Val Acc: 0.2299
# Epoch 16/10000, Tr Loss: 1.4243, Tr Acc: 0.2289, Val Loss: 1.4000, Val Acc: 0.2299
# Epoch 17/10000, Tr Loss: 1.4223, Tr Acc: 0.2537, Val Loss: 1.4002, Val Acc: 0.2299
# Epoch 18/10000, Tr Loss: 1.4326, Tr Acc: 0.2289, Val Loss: 1.4006, Val Acc: 0.2299
# Epoch 19/10000, Tr Loss: 1.4228, Tr Acc: 0.2985, Val Loss: 1.4009, Val Acc: 0.2299
# Epoch 20/10000, Tr Loss: 1.4283, Tr Acc: 0.2289, Val Loss: 1.4013, Val Acc: 0.2529
# Epoch 21/10000, Tr Loss: 1.4280, Tr Acc: 0.2637, Val Loss: 1.4016, Val Acc: 0.2644
# Epoch 22/10000, Tr Loss: 1.4141, Tr Acc: 0.2935, Val Loss: 1.4019, Val Acc: 0.2529
# Epoch 23/10000, Tr Loss: 1.4013, Tr Acc: 0.3085, Val Loss: 1.4022, Val Acc: 0.2529
# Epoch 24/10000, Tr Loss: 1.4150, Tr Acc: 0.2637, Val Loss: 1.4024, Val Acc: 0.2529
# Epoch 25/10000, Tr Loss: 1.4441, Tr Acc: 0.2587, Val Loss: 1.4026, Val Acc: 0.2529
# Epoch 26/10000, Tr Loss: 1.4096, Tr Acc: 0.2537, Val Loss: 1.4028, Val Acc: 0.2529
# Epoch 27/10000, Tr Loss: 1.4239, Tr Acc: 0.2488, Val Loss: 1.4030, Val Acc: 0.2529
# Epoch 28/10000, Tr Loss: 1.4359, Tr Acc: 0.2090, Val Loss: 1.4031, Val Acc: 0.2414
# Epoch 29/10000, Tr Loss: 1.4126, Tr Acc: 0.2985, Val Loss: 1.4032, Val Acc: 0.2414
# Epoch 30/10000, Tr Loss: 1.4310, Tr Acc: 0.2438, Val Loss: 1.4032, Val Acc: 0.2529
# Epoch 31/10000, Tr Loss: 1.4076, Tr Acc: 0.2388, Val Loss: 1.4033, Val Acc: 0.2759
# Epoch 32/10000, Tr Loss: 1.4057, Tr Acc: 0.2637, Val Loss: 1.4033, Val Acc: 0.2759
# Epoch 33/10000, Tr Loss: 1.4125, Tr Acc: 0.2537, Val Loss: 1.4032, Val Acc: 0.2759
# Epoch 34/10000, Tr Loss: 1.4091, Tr Acc: 0.2886, Val Loss: 1.4032, Val Acc: 0.2874
# Epoch 35/10000, Tr Loss: 1.4510, Tr Acc: 0.2537, Val Loss: 1.4031, Val Acc: 0.2759
# Epoch 36/10000, Tr Loss: 1.4512, Tr Acc: 0.2537, Val Loss: 1.4031, Val Acc: 0.2759
# Epoch 37/10000, Tr Loss: 1.4192, Tr Acc: 0.2587, Val Loss: 1.4030, Val Acc: 0.2644
# Epoch 38/10000, Tr Loss: 1.4381, Tr Acc: 0.2687, Val Loss: 1.4029, Val Acc: 0.2644
# Epoch 39/10000, Tr Loss: 1.3985, Tr Acc: 0.3035, Val Loss: 1.4028, Val Acc: 0.2644
# Epoch 40/10000, Tr Loss: 1.4047, Tr Acc: 0.3035, Val Loss: 1.4027, Val Acc: 0.2529
# Epoch 41/10000, Tr Loss: 1.4063, Tr Acc: 0.3085, Val Loss: 1.4026, Val Acc: 0.2529
# Epoch 42/10000, Tr Loss: 1.4124, Tr Acc: 0.2090, Val Loss: 1.4025, Val Acc: 0.2529
# Epoch 43/10000, Tr Loss: 1.4357, Tr Acc: 0.2736, Val Loss: 1.4024, Val Acc: 0.2414
# Epoch 44/10000, Tr Loss: 1.3988, Tr Acc: 0.2935, Val Loss: 1.4023, Val Acc: 0.2414
# Epoch 45/10000, Tr Loss: 1.4010, Tr Acc: 0.2687, Val Loss: 1.4022, Val Acc: 0.2414
# Epoch 46/10000, Tr Loss: 1.4203, Tr Acc: 0.2836, Val Loss: 1.4020, Val Acc: 0.2414
# Epoch 47/10000, Tr Loss: 1.4269, Tr Acc: 0.2438, Val Loss: 1.4019, Val Acc: 0.2414
# Epoch 48/10000, Tr Loss: 1.4275, Tr Acc: 0.2587, Val Loss: 1.4018, Val Acc: 0.2414
# Epoch 49/10000, Tr Loss: 1.4235, Tr Acc: 0.2587, Val Loss: 1.4017, Val Acc: 0.2414
# Epoch 50/10000, Tr Loss: 1.3850, Tr Acc: 0.2836, Val Loss: 1.4016, Val Acc: 0.2414
# Epoch 51/10000, Tr Loss: 1.4082, Tr Acc: 0.2736, Val Loss: 1.4014, Val Acc: 0.2529
# Epoch 52/10000, Tr Loss: 1.3970, Tr Acc: 0.2886, Val Loss: 1.4013, Val Acc: 0.2529
# Epoch 53/10000, Tr Loss: 1.3971, Tr Acc: 0.2687, Val Loss: 1.4012, Val Acc: 0.2529
# Epoch 54/10000, Tr Loss: 1.3944, Tr Acc: 0.2836, Val Loss: 1.4011, Val Acc: 0.2644
# Epoch 55/10000, Tr Loss: 1.3946, Tr Acc: 0.2687, Val Loss: 1.4009, Val Acc: 0.2644
# Epoch 56/10000, Tr Loss: 1.4147, Tr Acc: 0.2488, Val Loss: 1.4008, Val Acc: 0.2644
# Epoch 57/10000, Tr Loss: 1.3774, Tr Acc: 0.3284, Val Loss: 1.4007, Val Acc: 0.2644
# Epoch 58/10000, Tr Loss: 1.4016, Tr Acc: 0.2687, Val Loss: 1.4006, Val Acc: 0.2644
# Epoch 59/10000, Tr Loss: 1.4044, Tr Acc: 0.2587, Val Loss: 1.4005, Val Acc: 0.2529
# Epoch 60/10000, Tr Loss: 1.4393, Tr Acc: 0.2388, Val Loss: 1.4004, Val Acc: 0.2529
# Epoch 61/10000, Tr Loss: 1.3997, Tr Acc: 0.2637, Val Loss: 1.4003, Val Acc: 0.2529
# Epoch 62/10000, Tr Loss: 1.4046, Tr Acc: 0.3035, Val Loss: 1.4002, Val Acc: 0.2644
# Epoch 63/10000, Tr Loss: 1.3900, Tr Acc: 0.2886, Val Loss: 1.4001, Val Acc: 0.2644
# Epoch 64/10000, Tr Loss: 1.4230, Tr Acc: 0.2687, Val Loss: 1.4000, Val Acc: 0.2644
# Epoch 65/10000, Tr Loss: 1.3909, Tr Acc: 0.2836, Val Loss: 1.3999, Val Acc: 0.2644
# Epoch 66/10000, Tr Loss: 1.4125, Tr Acc: 0.2736, Val Loss: 1.3998, Val Acc: 0.2644
# Epoch 67/10000, Tr Loss: 1.3983, Tr Acc: 0.2786, Val Loss: 1.3997, Val Acc: 0.2644
# Epoch 68/10000, Tr Loss: 1.3972, Tr Acc: 0.2687, Val Loss: 1.3996, Val Acc: 0.2644
# Epoch 69/10000, Tr Loss: 1.3687, Tr Acc: 0.3184, Val Loss: 1.3995, Val Acc: 0.2644
# Epoch 70/10000, Tr Loss: 1.3554, Tr Acc: 0.2836, Val Loss: 1.3994, Val Acc: 0.2644
# Epoch 71/10000, Tr Loss: 1.3899, Tr Acc: 0.3134, Val Loss: 1.3993, Val Acc: 0.2644
# Epoch 72/10000, Tr Loss: 1.4013, Tr Acc: 0.2886, Val Loss: 1.3992, Val Acc: 0.2644
# Epoch 73/10000, Tr Loss: 1.3839, Tr Acc: 0.2985, Val Loss: 1.3991, Val Acc: 0.2644
# Epoch 74/10000, Tr Loss: 1.4053, Tr Acc: 0.2935, Val Loss: 1.3990, Val Acc: 0.2644
# Epoch 75/10000, Tr Loss: 1.4121, Tr Acc: 0.2488, Val Loss: 1.3989, Val Acc: 0.2644
# Epoch 76/10000, Tr Loss: 1.3874, Tr Acc: 0.2886, Val Loss: 1.3988, Val Acc: 0.2644
# Epoch 77/10000, Tr Loss: 1.4076, Tr Acc: 0.2886, Val Loss: 1.3987, Val Acc: 0.2529
# Epoch 78/10000, Tr Loss: 1.3633, Tr Acc: 0.3184, Val Loss: 1.3986, Val Acc: 0.2529
# Epoch 79/10000, Tr Loss: 1.4054, Tr Acc: 0.2985, Val Loss: 1.3985, Val Acc: 0.2529
# Epoch 80/10000, Tr Loss: 1.3852, Tr Acc: 0.3234, Val Loss: 1.3984, Val Acc: 0.2414
# Epoch 81/10000, Tr Loss: 1.3896, Tr Acc: 0.2687, Val Loss: 1.3983, Val Acc: 0.2414
# Epoch 82/10000, Tr Loss: 1.4155, Tr Acc: 0.2488, Val Loss: 1.3982, Val Acc: 0.2414
# Epoch 83/10000, Tr Loss: 1.3878, Tr Acc: 0.3085, Val Loss: 1.3981, Val Acc: 0.2414
# Epoch 84/10000, Tr Loss: 1.3714, Tr Acc: 0.3134, Val Loss: 1.3980, Val Acc: 0.2414
# Epoch 85/10000, Tr Loss: 1.3743, Tr Acc: 0.3184, Val Loss: 1.3979, Val Acc: 0.2414
# Epoch 86/10000, Tr Loss: 1.3576, Tr Acc: 0.3682, Val Loss: 1.3978, Val Acc: 0.2414
# Epoch 87/10000, Tr Loss: 1.3750, Tr Acc: 0.3085, Val Loss: 1.3977, Val Acc: 0.2414
# Epoch 88/10000, Tr Loss: 1.3701, Tr Acc: 0.3035, Val Loss: 1.3976, Val Acc: 0.2414
# Epoch 89/10000, Tr Loss: 1.3853, Tr Acc: 0.2935, Val Loss: 1.3975, Val Acc: 0.2414
# Epoch 90/10000, Tr Loss: 1.3691, Tr Acc: 0.3234, Val Loss: 1.3974, Val Acc: 0.2414
# Epoch 91/10000, Tr Loss: 1.3852, Tr Acc: 0.3333, Val Loss: 1.3973, Val Acc: 0.2414
# Epoch 92/10000, Tr Loss: 1.3708, Tr Acc: 0.2687, Val Loss: 1.3972, Val Acc: 0.2414
# Epoch 93/10000, Tr Loss: 1.3402, Tr Acc: 0.3532, Val Loss: 1.3971, Val Acc: 0.2414
# Epoch 94/10000, Tr Loss: 1.3769, Tr Acc: 0.3085, Val Loss: 1.3970, Val Acc: 0.2529
# Epoch 95/10000, Tr Loss: 1.3669, Tr Acc: 0.2985, Val Loss: 1.3969, Val Acc: 0.2529
# Epoch 96/10000, Tr Loss: 1.3524, Tr Acc: 0.3184, Val Loss: 1.3968, Val Acc: 0.2529
# Epoch 97/10000, Tr Loss: 1.3853, Tr Acc: 0.2786, Val Loss: 1.3966, Val Acc: 0.2529
# Epoch 98/10000, Tr Loss: 1.3610, Tr Acc: 0.3532, Val Loss: 1.3966, Val Acc: 0.2529
# Epoch 99/10000, Tr Loss: 1.3507, Tr Acc: 0.3134, Val Loss: 1.3965, Val Acc: 0.2529
# Epoch 100/10000, Tr Loss: 1.3764, Tr Acc: 0.3184, Val Loss: 1.3963, Val Acc: 0.2529
# Epoch 101/10000, Tr Loss: 1.3623, Tr Acc: 0.3284, Val Loss: 1.3963, Val Acc: 0.2529
# Epoch 102/10000, Tr Loss: 1.3656, Tr Acc: 0.3383, Val Loss: 1.3961, Val Acc: 0.2529
# Epoch 103/10000, Tr Loss: 1.3930, Tr Acc: 0.3134, Val Loss: 1.3960, Val Acc: 0.2529
# Epoch 104/10000, Tr Loss: 1.3695, Tr Acc: 0.2985, Val Loss: 1.3959, Val Acc: 0.2529
# Epoch 105/10000, Tr Loss: 1.3968, Tr Acc: 0.2786, Val Loss: 1.3958, Val Acc: 0.2529
# Epoch 106/10000, Tr Loss: 1.3646, Tr Acc: 0.3333, Val Loss: 1.3957, Val Acc: 0.2529
# Epoch 107/10000, Tr Loss: 1.3985, Tr Acc: 0.3035, Val Loss: 1.3956, Val Acc: 0.2529
# Epoch 108/10000, Tr Loss: 1.3928, Tr Acc: 0.3085, Val Loss: 1.3955, Val Acc: 0.2529
# Epoch 109/10000, Tr Loss: 1.3604, Tr Acc: 0.3035, Val Loss: 1.3954, Val Acc: 0.2529
# Epoch 110/10000, Tr Loss: 1.3253, Tr Acc: 0.3483, Val Loss: 1.3952, Val Acc: 0.2414
# Epoch 111/10000, Tr Loss: 1.3736, Tr Acc: 0.2886, Val Loss: 1.3952, Val Acc: 0.2529
# Epoch 112/10000, Tr Loss: 1.3585, Tr Acc: 0.3184, Val Loss: 1.3951, Val Acc: 0.2529
# Epoch 113/10000, Tr Loss: 1.3685, Tr Acc: 0.3085, Val Loss: 1.3950, Val Acc: 0.2529
# Epoch 114/10000, Tr Loss: 1.3553, Tr Acc: 0.3134, Val Loss: 1.3949, Val Acc: 0.2529
# Epoch 115/10000, Tr Loss: 1.3482, Tr Acc: 0.3433, Val Loss: 1.3947, Val Acc: 0.2529
# Epoch 116/10000, Tr Loss: 1.3824, Tr Acc: 0.2886, Val Loss: 1.3946, Val Acc: 0.2529
# Epoch 117/10000, Tr Loss: 1.3422, Tr Acc: 0.4080, Val Loss: 1.3945, Val Acc: 0.2414
# Epoch 118/10000, Tr Loss: 1.3381, Tr Acc: 0.3731, Val Loss: 1.3944, Val Acc: 0.2414
# Epoch 119/10000, Tr Loss: 1.3330, Tr Acc: 0.3483, Val Loss: 1.3943, Val Acc: 0.2414
# Epoch 120/10000, Tr Loss: 1.3707, Tr Acc: 0.3085, Val Loss: 1.3942, Val Acc: 0.2414
# Epoch 121/10000, Tr Loss: 1.3301, Tr Acc: 0.3333, Val Loss: 1.3941, Val Acc: 0.2414
# Epoch 122/10000, Tr Loss: 1.3664, Tr Acc: 0.3134, Val Loss: 1.3940, Val Acc: 0.2414
# Epoch 123/10000, Tr Loss: 1.3735, Tr Acc: 0.2836, Val Loss: 1.3939, Val Acc: 0.2414
# Epoch 124/10000, Tr Loss: 1.3504, Tr Acc: 0.3433, Val Loss: 1.3938, Val Acc: 0.2414
# Epoch 125/10000, Tr Loss: 1.3881, Tr Acc: 0.2587, Val Loss: 1.3937, Val Acc: 0.2414
# Epoch 126/10000, Tr Loss: 1.4134, Tr Acc: 0.2786, Val Loss: 1.3936, Val Acc: 0.2414
# Epoch 127/10000, Tr Loss: 1.3610, Tr Acc: 0.3532, Val Loss: 1.3935, Val Acc: 0.2414
# Epoch 128/10000, Tr Loss: 1.3733, Tr Acc: 0.3284, Val Loss: 1.3934, Val Acc: 0.2414
# Epoch 129/10000, Tr Loss: 1.3521, Tr Acc: 0.3134, Val Loss: 1.3933, Val Acc: 0.2414
# Epoch 130/10000, Tr Loss: 1.3578, Tr Acc: 0.3731, Val Loss: 1.3932, Val Acc: 0.2414
# Epoch 131/10000, Tr Loss: 1.3595, Tr Acc: 0.3134, Val Loss: 1.3931, Val Acc: 0.2414
# Epoch 132/10000, Tr Loss: 1.3417, Tr Acc: 0.3582, Val Loss: 1.3930, Val Acc: 0.2414
# Epoch 133/10000, Tr Loss: 1.3781, Tr Acc: 0.3284, Val Loss: 1.3929, Val Acc: 0.2414
# Epoch 134/10000, Tr Loss: 1.3428, Tr Acc: 0.3781, Val Loss: 1.3928, Val Acc: 0.2414
# Epoch 135/10000, Tr Loss: 1.3302, Tr Acc: 0.3532, Val Loss: 1.3927, Val Acc: 0.2414
# Epoch 136/10000, Tr Loss: 1.3427, Tr Acc: 0.3632, Val Loss: 1.3927, Val Acc: 0.2414
# Epoch 137/10000, Tr Loss: 1.3218, Tr Acc: 0.3582, Val Loss: 1.3925, Val Acc: 0.2414
# Epoch 138/10000, Tr Loss: 1.3492, Tr Acc: 0.3632, Val Loss: 1.3925, Val Acc: 0.2299
# Epoch 139/10000, Tr Loss: 1.3697, Tr Acc: 0.3085, Val Loss: 1.3924, Val Acc: 0.2299
# Epoch 140/10000, Tr Loss: 1.3414, Tr Acc: 0.3831, Val Loss: 1.3923, Val Acc: 0.2299
# Epoch 141/10000, Tr Loss: 1.3457, Tr Acc: 0.3184, Val Loss: 1.3922, Val Acc: 0.2299
# Epoch 142/10000, Tr Loss: 1.3471, Tr Acc: 0.3532, Val Loss: 1.3921, Val Acc: 0.2299
# Epoch 143/10000, Tr Loss: 1.3300, Tr Acc: 0.3433, Val Loss: 1.3920, Val Acc: 0.2299
# Epoch 144/10000, Tr Loss: 1.3257, Tr Acc: 0.3632, Val Loss: 1.3919, Val Acc: 0.2299
# Epoch 145/10000, Tr Loss: 1.3524, Tr Acc: 0.3483, Val Loss: 1.3918, Val Acc: 0.2299
# Epoch 146/10000, Tr Loss: 1.3475, Tr Acc: 0.3383, Val Loss: 1.3917, Val Acc: 0.2299
# Epoch 147/10000, Tr Loss: 1.3513, Tr Acc: 0.3333, Val Loss: 1.3916, Val Acc: 0.2299
# Epoch 148/10000, Tr Loss: 1.3668, Tr Acc: 0.2836, Val Loss: 1.3915, Val Acc: 0.2299
# Epoch 149/10000, Tr Loss: 1.3325, Tr Acc: 0.3134, Val Loss: 1.3914, Val Acc: 0.2299
# Epoch 150/10000, Tr Loss: 1.3367, Tr Acc: 0.3881, Val Loss: 1.3913, Val Acc: 0.2299
# Epoch 151/10000, Tr Loss: 1.3685, Tr Acc: 0.3184, Val Loss: 1.3912, Val Acc: 0.2299
# Epoch 152/10000, Tr Loss: 1.3278, Tr Acc: 0.3284, Val Loss: 1.3911, Val Acc: 0.2299
# Epoch 153/10000, Tr Loss: 1.3397, Tr Acc: 0.3532, Val Loss: 1.3909, Val Acc: 0.2299
# Epoch 154/10000, Tr Loss: 1.3470, Tr Acc: 0.3930, Val Loss: 1.3908, Val Acc: 0.2299
# Epoch 155/10000, Tr Loss: 1.3068, Tr Acc: 0.3532, Val Loss: 1.3907, Val Acc: 0.2299
# Epoch 156/10000, Tr Loss: 1.3269, Tr Acc: 0.3433, Val Loss: 1.3906, Val Acc: 0.2299
# Epoch 157/10000, Tr Loss: 1.3284, Tr Acc: 0.3781, Val Loss: 1.3905, Val Acc: 0.2299
# Epoch 158/10000, Tr Loss: 1.3011, Tr Acc: 0.4378, Val Loss: 1.3905, Val Acc: 0.2299
# Epoch 159/10000, Tr Loss: 1.3360, Tr Acc: 0.3881, Val Loss: 1.3904, Val Acc: 0.2299
# Epoch 160/10000, Tr Loss: 1.3535, Tr Acc: 0.3035, Val Loss: 1.3903, Val Acc: 0.2299
# Epoch 161/10000, Tr Loss: 1.3647, Tr Acc: 0.3433, Val Loss: 1.3902, Val Acc: 0.2299
# Epoch 162/10000, Tr Loss: 1.3279, Tr Acc: 0.3731, Val Loss: 1.3902, Val Acc: 0.2299
# Epoch 163/10000, Tr Loss: 1.3154, Tr Acc: 0.3980, Val Loss: 1.3901, Val Acc: 0.2299
# Epoch 164/10000, Tr Loss: 1.3764, Tr Acc: 0.3184, Val Loss: 1.3900, Val Acc: 0.2299
# Epoch 165/10000, Tr Loss: 1.3579, Tr Acc: 0.3682, Val Loss: 1.3899, Val Acc: 0.2299
# Epoch 166/10000, Tr Loss: 1.3663, Tr Acc: 0.3035, Val Loss: 1.3898, Val Acc: 0.2299
# Epoch 167/10000, Tr Loss: 1.3328, Tr Acc: 0.3731, Val Loss: 1.3897, Val Acc: 0.2414
# Epoch 168/10000, Tr Loss: 1.3121, Tr Acc: 0.4080, Val Loss: 1.3896, Val Acc: 0.2414
# Epoch 169/10000, Tr Loss: 1.3167, Tr Acc: 0.3682, Val Loss: 1.3895, Val Acc: 0.2414
# Epoch 170/10000, Tr Loss: 1.3370, Tr Acc: 0.3731, Val Loss: 1.3894, Val Acc: 0.2414
# Epoch 171/10000, Tr Loss: 1.3147, Tr Acc: 0.3632, Val Loss: 1.3893, Val Acc: 0.2414
# Epoch 172/10000, Tr Loss: 1.3181, Tr Acc: 0.3831, Val Loss: 1.3892, Val Acc: 0.2414
# Epoch 173/10000, Tr Loss: 1.2979, Tr Acc: 0.3831, Val Loss: 1.3891, Val Acc: 0.2414
# Epoch 174/10000, Tr Loss: 1.3296, Tr Acc: 0.3731, Val Loss: 1.3890, Val Acc: 0.2414
# Epoch 175/10000, Tr Loss: 1.3130, Tr Acc: 0.4179, Val Loss: 1.3889, Val Acc: 0.2414
# Epoch 176/10000, Tr Loss: 1.3345, Tr Acc: 0.3085, Val Loss: 1.3889, Val Acc: 0.2414
# Epoch 177/10000, Tr Loss: 1.3163, Tr Acc: 0.3632, Val Loss: 1.3888, Val Acc: 0.2414
# Epoch 178/10000, Tr Loss: 1.3231, Tr Acc: 0.3781, Val Loss: 1.3887, Val Acc: 0.2414
# Epoch 179/10000, Tr Loss: 1.3148, Tr Acc: 0.4179, Val Loss: 1.3886, Val Acc: 0.2414
# Epoch 180/10000, Tr Loss: 1.3193, Tr Acc: 0.3184, Val Loss: 1.3885, Val Acc: 0.2414
# Epoch 181/10000, Tr Loss: 1.2882, Tr Acc: 0.4328, Val Loss: 1.3884, Val Acc: 0.2414
# Epoch 182/10000, Tr Loss: 1.3141, Tr Acc: 0.3930, Val Loss: 1.3883, Val Acc: 0.2414
# Epoch 183/10000, Tr Loss: 1.3050, Tr Acc: 0.4279, Val Loss: 1.3882, Val Acc: 0.2414
# Epoch 184/10000, Tr Loss: 1.2927, Tr Acc: 0.4229, Val Loss: 1.3881, Val Acc: 0.2414
# Epoch 185/10000, Tr Loss: 1.3024, Tr Acc: 0.3831, Val Loss: 1.3881, Val Acc: 0.2414
# Epoch 186/10000, Tr Loss: 1.3278, Tr Acc: 0.3632, Val Loss: 1.3880, Val Acc: 0.2414
# Epoch 187/10000, Tr Loss: 1.2930, Tr Acc: 0.3731, Val Loss: 1.3879, Val Acc: 0.2414
# Epoch 188/10000, Tr Loss: 1.2925, Tr Acc: 0.3980, Val Loss: 1.3878, Val Acc: 0.2414
# Epoch 189/10000, Tr Loss: 1.3026, Tr Acc: 0.4080, Val Loss: 1.3877, Val Acc: 0.2414
# Epoch 190/10000, Tr Loss: 1.3244, Tr Acc: 0.3682, Val Loss: 1.3876, Val Acc: 0.2414
# Epoch 191/10000, Tr Loss: 1.3302, Tr Acc: 0.3333, Val Loss: 1.3876, Val Acc: 0.2414
# Epoch 192/10000, Tr Loss: 1.2960, Tr Acc: 0.3980, Val Loss: 1.3875, Val Acc: 0.2414
# Epoch 193/10000, Tr Loss: 1.3044, Tr Acc: 0.4279, Val Loss: 1.3874, Val Acc: 0.2414
# Epoch 194/10000, Tr Loss: 1.2870, Tr Acc: 0.4428, Val Loss: 1.3873, Val Acc: 0.2414
# Epoch 195/10000, Tr Loss: 1.2932, Tr Acc: 0.4229, Val Loss: 1.3872, Val Acc: 0.2414
# Epoch 196/10000, Tr Loss: 1.3428, Tr Acc: 0.3284, Val Loss: 1.3871, Val Acc: 0.2529
# Epoch 197/10000, Tr Loss: 1.2960, Tr Acc: 0.4129, Val Loss: 1.3870, Val Acc: 0.2529
# Epoch 198/10000, Tr Loss: 1.2768, Tr Acc: 0.3930, Val Loss: 1.3869, Val Acc: 0.2529
# Epoch 199/10000, Tr Loss: 1.2930, Tr Acc: 0.4328, Val Loss: 1.3868, Val Acc: 0.2529
# Epoch 200/10000, Tr Loss: 1.3374, Tr Acc: 0.3483, Val Loss: 1.3867, Val Acc: 0.2529
# Epoch 201/10000, Tr Loss: 1.2937, Tr Acc: 0.3980, Val Loss: 1.3867, Val Acc: 0.2529
# Epoch 202/10000, Tr Loss: 1.2983, Tr Acc: 0.3632, Val Loss: 1.3866, Val Acc: 0.2529
# Epoch 203/10000, Tr Loss: 1.3052, Tr Acc: 0.4030, Val Loss: 1.3865, Val Acc: 0.2529
# Epoch 204/10000, Tr Loss: 1.2935, Tr Acc: 0.4129, Val Loss: 1.3864, Val Acc: 0.2529
# Epoch 205/10000, Tr Loss: 1.2934, Tr Acc: 0.3682, Val Loss: 1.3863, Val Acc: 0.2529
# Epoch 206/10000, Tr Loss: 1.2918, Tr Acc: 0.4179, Val Loss: 1.3862, Val Acc: 0.2529
# Epoch 207/10000, Tr Loss: 1.3289, Tr Acc: 0.3532, Val Loss: 1.3861, Val Acc: 0.2644
# Epoch 208/10000, Tr Loss: 1.2884, Tr Acc: 0.4378, Val Loss: 1.3860, Val Acc: 0.2644
# Epoch 209/10000, Tr Loss: 1.2915, Tr Acc: 0.3930, Val Loss: 1.3859, Val Acc: 0.2644
# Epoch 210/10000, Tr Loss: 1.2902, Tr Acc: 0.4428, Val Loss: 1.3858, Val Acc: 0.2644
# Epoch 211/10000, Tr Loss: 1.2784, Tr Acc: 0.4577, Val Loss: 1.3857, Val Acc: 0.2644
# Epoch 212/10000, Tr Loss: 1.2851, Tr Acc: 0.4428, Val Loss: 1.3856, Val Acc: 0.2644
# Epoch 213/10000, Tr Loss: 1.2999, Tr Acc: 0.3781, Val Loss: 1.3855, Val Acc: 0.2644
# Epoch 214/10000, Tr Loss: 1.2957, Tr Acc: 0.4279, Val Loss: 1.3854, Val Acc: 0.2644
# Epoch 215/10000, Tr Loss: 1.2913, Tr Acc: 0.4279, Val Loss: 1.3853, Val Acc: 0.2644
# Epoch 216/10000, Tr Loss: 1.2839, Tr Acc: 0.4328, Val Loss: 1.3852, Val Acc: 0.2644
# Epoch 217/10000, Tr Loss: 1.2717, Tr Acc: 0.4129, Val Loss: 1.3852, Val Acc: 0.2644
# Epoch 218/10000, Tr Loss: 1.2722, Tr Acc: 0.4279, Val Loss: 1.3851, Val Acc: 0.2759
# Epoch 219/10000, Tr Loss: 1.2794, Tr Acc: 0.3781, Val Loss: 1.3850, Val Acc: 0.2759
# Epoch 220/10000, Tr Loss: 1.2931, Tr Acc: 0.4328, Val Loss: 1.3850, Val Acc: 0.2759
# Epoch 221/10000, Tr Loss: 1.3056, Tr Acc: 0.3383, Val Loss: 1.3849, Val Acc: 0.2759
# Epoch 222/10000, Tr Loss: 1.2501, Tr Acc: 0.4726, Val Loss: 1.3848, Val Acc: 0.2759
# Epoch 223/10000, Tr Loss: 1.2900, Tr Acc: 0.3881, Val Loss: 1.3847, Val Acc: 0.2759
# Epoch 224/10000, Tr Loss: 1.3074, Tr Acc: 0.3930, Val Loss: 1.3846, Val Acc: 0.2759
# Epoch 225/10000, Tr Loss: 1.2837, Tr Acc: 0.4577, Val Loss: 1.3846, Val Acc: 0.2759
# Epoch 226/10000, Tr Loss: 1.2384, Tr Acc: 0.4627, Val Loss: 1.3845, Val Acc: 0.2759
# Epoch 227/10000, Tr Loss: 1.2656, Tr Acc: 0.4279, Val Loss: 1.3845, Val Acc: 0.2759
# Epoch 228/10000, Tr Loss: 1.2916, Tr Acc: 0.3682, Val Loss: 1.3844, Val Acc: 0.2759
# Epoch 229/10000, Tr Loss: 1.2645, Tr Acc: 0.4229, Val Loss: 1.3843, Val Acc: 0.2759
# Epoch 230/10000, Tr Loss: 1.2938, Tr Acc: 0.3881, Val Loss: 1.3843, Val Acc: 0.2644
# Epoch 231/10000, Tr Loss: 1.2629, Tr Acc: 0.4279, Val Loss: 1.3842, Val Acc: 0.2644
# Epoch 232/10000, Tr Loss: 1.2713, Tr Acc: 0.3930, Val Loss: 1.3841, Val Acc: 0.2644
# Epoch 233/10000, Tr Loss: 1.2639, Tr Acc: 0.4080, Val Loss: 1.3840, Val Acc: 0.2644
# Epoch 234/10000, Tr Loss: 1.3001, Tr Acc: 0.3582, Val Loss: 1.3839, Val Acc: 0.2759
# Epoch 235/10000, Tr Loss: 1.2878, Tr Acc: 0.4179, Val Loss: 1.3838, Val Acc: 0.2759
# Epoch 236/10000, Tr Loss: 1.2766, Tr Acc: 0.4428, Val Loss: 1.3837, Val Acc: 0.2759
# Epoch 237/10000, Tr Loss: 1.2366, Tr Acc: 0.4876, Val Loss: 1.3836, Val Acc: 0.2874
# Epoch 238/10000, Tr Loss: 1.2870, Tr Acc: 0.3831, Val Loss: 1.3835, Val Acc: 0.2874
# Epoch 239/10000, Tr Loss: 1.2618, Tr Acc: 0.4478, Val Loss: 1.3835, Val Acc: 0.2874
# Epoch 240/10000, Tr Loss: 1.2754, Tr Acc: 0.4030, Val Loss: 1.3834, Val Acc: 0.2874
# Epoch 241/10000, Tr Loss: 1.2954, Tr Acc: 0.4279, Val Loss: 1.3833, Val Acc: 0.2874
# Epoch 242/10000, Tr Loss: 1.2454, Tr Acc: 0.4726, Val Loss: 1.3832, Val Acc: 0.2874
# Epoch 243/10000, Tr Loss: 1.2818, Tr Acc: 0.3980, Val Loss: 1.3831, Val Acc: 0.2874
# Epoch 244/10000, Tr Loss: 1.2764, Tr Acc: 0.4279, Val Loss: 1.3830, Val Acc: 0.2874
# Epoch 245/10000, Tr Loss: 1.2986, Tr Acc: 0.4179, Val Loss: 1.3830, Val Acc: 0.2874
# Epoch 246/10000, Tr Loss: 1.2695, Tr Acc: 0.4527, Val Loss: 1.3829, Val Acc: 0.2874
# Epoch 247/10000, Tr Loss: 1.2742, Tr Acc: 0.4577, Val Loss: 1.3828, Val Acc: 0.2874
# Epoch 248/10000, Tr Loss: 1.2423, Tr Acc: 0.4776, Val Loss: 1.3827, Val Acc: 0.2759
# Epoch 249/10000, Tr Loss: 1.2733, Tr Acc: 0.4428, Val Loss: 1.3827, Val Acc: 0.2759
# Epoch 250/10000, Tr Loss: 1.2867, Tr Acc: 0.4179, Val Loss: 1.3826, Val Acc: 0.2759
# Epoch 251/10000, Tr Loss: 1.2623, Tr Acc: 0.4776, Val Loss: 1.3825, Val Acc: 0.2759
# Epoch 252/10000, Tr Loss: 1.2907, Tr Acc: 0.4229, Val Loss: 1.3825, Val Acc: 0.2759
# Epoch 253/10000, Tr Loss: 1.2716, Tr Acc: 0.4129, Val Loss: 1.3824, Val Acc: 0.2759
# Epoch 254/10000, Tr Loss: 1.3057, Tr Acc: 0.3930, Val Loss: 1.3823, Val Acc: 0.2759
# Epoch 255/10000, Tr Loss: 1.2587, Tr Acc: 0.4378, Val Loss: 1.3823, Val Acc: 0.2759
# Epoch 256/10000, Tr Loss: 1.2600, Tr Acc: 0.4776, Val Loss: 1.3822, Val Acc: 0.2759
# Epoch 257/10000, Tr Loss: 1.2614, Tr Acc: 0.4577, Val Loss: 1.3821, Val Acc: 0.2759
# Epoch 258/10000, Tr Loss: 1.2843, Tr Acc: 0.3831, Val Loss: 1.3820, Val Acc: 0.2759
# Epoch 259/10000, Tr Loss: 1.3140, Tr Acc: 0.3483, Val Loss: 1.3819, Val Acc: 0.2759
# Epoch 260/10000, Tr Loss: 1.2521, Tr Acc: 0.4577, Val Loss: 1.3819, Val Acc: 0.2759
# Epoch 261/10000, Tr Loss: 1.2434, Tr Acc: 0.4577, Val Loss: 1.3818, Val Acc: 0.2759
# Epoch 262/10000, Tr Loss: 1.2380, Tr Acc: 0.4378, Val Loss: 1.3817, Val Acc: 0.2874
# Epoch 263/10000, Tr Loss: 1.2708, Tr Acc: 0.4030, Val Loss: 1.3816, Val Acc: 0.2874
# Epoch 264/10000, Tr Loss: 1.2239, Tr Acc: 0.5274, Val Loss: 1.3815, Val Acc: 0.2874
# Epoch 265/10000, Tr Loss: 1.2446, Tr Acc: 0.4776, Val Loss: 1.3815, Val Acc: 0.2874
# Epoch 266/10000, Tr Loss: 1.2441, Tr Acc: 0.4975, Val Loss: 1.3814, Val Acc: 0.2759
# Epoch 267/10000, Tr Loss: 1.2274, Tr Acc: 0.4677, Val Loss: 1.3813, Val Acc: 0.2759
# Epoch 268/10000, Tr Loss: 1.2487, Tr Acc: 0.4826, Val Loss: 1.3812, Val Acc: 0.2759
# Epoch 269/10000, Tr Loss: 1.2734, Tr Acc: 0.4129, Val Loss: 1.3811, Val Acc: 0.2759
# Epoch 270/10000, Tr Loss: 1.2900, Tr Acc: 0.4577, Val Loss: 1.3810, Val Acc: 0.2759
# Epoch 271/10000, Tr Loss: 1.2692, Tr Acc: 0.3980, Val Loss: 1.3809, Val Acc: 0.2759
# Epoch 272/10000, Tr Loss: 1.2125, Tr Acc: 0.4925, Val Loss: 1.3809, Val Acc: 0.2759
# Epoch 273/10000, Tr Loss: 1.2457, Tr Acc: 0.4527, Val Loss: 1.3808, Val Acc: 0.2759
# Epoch 274/10000, Tr Loss: 1.2638, Tr Acc: 0.4428, Val Loss: 1.3807, Val Acc: 0.2759
# Epoch 275/10000, Tr Loss: 1.2339, Tr Acc: 0.4925, Val Loss: 1.3806, Val Acc: 0.2759
# Epoch 276/10000, Tr Loss: 1.2469, Tr Acc: 0.4726, Val Loss: 1.3806, Val Acc: 0.2759
# Epoch 277/10000, Tr Loss: 1.2749, Tr Acc: 0.4378, Val Loss: 1.3805, Val Acc: 0.2759
# Epoch 278/10000, Tr Loss: 1.2183, Tr Acc: 0.5124, Val Loss: 1.3804, Val Acc: 0.2759
# Epoch 279/10000, Tr Loss: 1.2070, Tr Acc: 0.4876, Val Loss: 1.3803, Val Acc: 0.2759
# Epoch 280/10000, Tr Loss: 1.2550, Tr Acc: 0.4478, Val Loss: 1.3803, Val Acc: 0.2759
# Epoch 281/10000, Tr Loss: 1.2524, Tr Acc: 0.4876, Val Loss: 1.3802, Val Acc: 0.2759
# Epoch 282/10000, Tr Loss: 1.2571, Tr Acc: 0.4627, Val Loss: 1.3801, Val Acc: 0.2759
# Epoch 283/10000, Tr Loss: 1.2820, Tr Acc: 0.3980, Val Loss: 1.3801, Val Acc: 0.2759
# Epoch 284/10000, Tr Loss: 1.2266, Tr Acc: 0.4627, Val Loss: 1.3800, Val Acc: 0.2759
# Epoch 285/10000, Tr Loss: 1.2484, Tr Acc: 0.4776, Val Loss: 1.3799, Val Acc: 0.2759
# Epoch 286/10000, Tr Loss: 1.2330, Tr Acc: 0.4627, Val Loss: 1.3799, Val Acc: 0.2759
# Epoch 287/10000, Tr Loss: 1.2553, Tr Acc: 0.4776, Val Loss: 1.3798, Val Acc: 0.2759
# Epoch 288/10000, Tr Loss: 1.2429, Tr Acc: 0.4577, Val Loss: 1.3798, Val Acc: 0.2759
# Epoch 289/10000, Tr Loss: 1.2462, Tr Acc: 0.4627, Val Loss: 1.3797, Val Acc: 0.2759
# Epoch 290/10000, Tr Loss: 1.2239, Tr Acc: 0.5323, Val Loss: 1.3797, Val Acc: 0.2759
# Epoch 291/10000, Tr Loss: 1.2374, Tr Acc: 0.4627, Val Loss: 1.3796, Val Acc: 0.2759
# Epoch 292/10000, Tr Loss: 1.2632, Tr Acc: 0.4328, Val Loss: 1.3795, Val Acc: 0.2759
# Epoch 293/10000, Tr Loss: 1.2259, Tr Acc: 0.5224, Val Loss: 1.3795, Val Acc: 0.2759
# Epoch 294/10000, Tr Loss: 1.2488, Tr Acc: 0.4179, Val Loss: 1.3794, Val Acc: 0.2759
# Epoch 295/10000, Tr Loss: 1.2290, Tr Acc: 0.4677, Val Loss: 1.3794, Val Acc: 0.2759
# Epoch 296/10000, Tr Loss: 1.2363, Tr Acc: 0.4776, Val Loss: 1.3793, Val Acc: 0.2759
# Epoch 297/10000, Tr Loss: 1.2418, Tr Acc: 0.5124, Val Loss: 1.3793, Val Acc: 0.2759
# Epoch 298/10000, Tr Loss: 1.2283, Tr Acc: 0.4627, Val Loss: 1.3792, Val Acc: 0.2759
# Epoch 299/10000, Tr Loss: 1.2377, Tr Acc: 0.4776, Val Loss: 1.3791, Val Acc: 0.2759
# Epoch 300/10000, Tr Loss: 1.2167, Tr Acc: 0.4776, Val Loss: 1.3791, Val Acc: 0.2759
# Epoch 301/10000, Tr Loss: 1.2599, Tr Acc: 0.4726, Val Loss: 1.3790, Val Acc: 0.2759
# Epoch 302/10000, Tr Loss: 1.2382, Tr Acc: 0.4826, Val Loss: 1.3789, Val Acc: 0.2759
# Epoch 303/10000, Tr Loss: 1.2238, Tr Acc: 0.4478, Val Loss: 1.3788, Val Acc: 0.2759
# Epoch 304/10000, Tr Loss: 1.2331, Tr Acc: 0.4627, Val Loss: 1.3788, Val Acc: 0.2759
# Epoch 305/10000, Tr Loss: 1.2253, Tr Acc: 0.4677, Val Loss: 1.3787, Val Acc: 0.2759
# Epoch 306/10000, Tr Loss: 1.2550, Tr Acc: 0.4677, Val Loss: 1.3787, Val Acc: 0.2759
# Epoch 307/10000, Tr Loss: 1.2270, Tr Acc: 0.5224, Val Loss: 1.3786, Val Acc: 0.2644
# Epoch 308/10000, Tr Loss: 1.2393, Tr Acc: 0.5174, Val Loss: 1.3786, Val Acc: 0.2644
# Epoch 309/10000, Tr Loss: 1.2393, Tr Acc: 0.4279, Val Loss: 1.3785, Val Acc: 0.2644
# Epoch 310/10000, Tr Loss: 1.2300, Tr Acc: 0.4776, Val Loss: 1.3784, Val Acc: 0.2644
# Epoch 311/10000, Tr Loss: 1.2298, Tr Acc: 0.4826, Val Loss: 1.3784, Val Acc: 0.2759
# Epoch 312/10000, Tr Loss: 1.2308, Tr Acc: 0.5423, Val Loss: 1.3783, Val Acc: 0.2759
# Epoch 313/10000, Tr Loss: 1.2074, Tr Acc: 0.5174, Val Loss: 1.3782, Val Acc: 0.2759
# Epoch 314/10000, Tr Loss: 1.2218, Tr Acc: 0.5075, Val Loss: 1.3782, Val Acc: 0.2759
# Epoch 315/10000, Tr Loss: 1.2129, Tr Acc: 0.5224, Val Loss: 1.3781, Val Acc: 0.2759
# Epoch 316/10000, Tr Loss: 1.2210, Tr Acc: 0.4876, Val Loss: 1.3780, Val Acc: 0.2874
# Epoch 317/10000, Tr Loss: 1.2301, Tr Acc: 0.4677, Val Loss: 1.3780, Val Acc: 0.2874
# Epoch 318/10000, Tr Loss: 1.2186, Tr Acc: 0.5124, Val Loss: 1.3779, Val Acc: 0.2874
# Epoch 319/10000, Tr Loss: 1.2093, Tr Acc: 0.5323, Val Loss: 1.3779, Val Acc: 0.2874
# Epoch 320/10000, Tr Loss: 1.2070, Tr Acc: 0.5373, Val Loss: 1.3778, Val Acc: 0.2874
# Epoch 321/10000, Tr Loss: 1.2469, Tr Acc: 0.4826, Val Loss: 1.3777, Val Acc: 0.2874
# Epoch 322/10000, Tr Loss: 1.2021, Tr Acc: 0.5274, Val Loss: 1.3776, Val Acc: 0.2874
# Epoch 323/10000, Tr Loss: 1.2550, Tr Acc: 0.4229, Val Loss: 1.3775, Val Acc: 0.2874
# Epoch 324/10000, Tr Loss: 1.2444, Tr Acc: 0.4726, Val Loss: 1.3775, Val Acc: 0.2874
# Epoch 325/10000, Tr Loss: 1.2377, Tr Acc: 0.4428, Val Loss: 1.3774, Val Acc: 0.2874
# Epoch 326/10000, Tr Loss: 1.2403, Tr Acc: 0.4677, Val Loss: 1.3773, Val Acc: 0.2874
# Epoch 327/10000, Tr Loss: 1.2203, Tr Acc: 0.4776, Val Loss: 1.3772, Val Acc: 0.2874
# Epoch 328/10000, Tr Loss: 1.2251, Tr Acc: 0.4876, Val Loss: 1.3772, Val Acc: 0.2874
# Epoch 329/10000, Tr Loss: 1.2083, Tr Acc: 0.5423, Val Loss: 1.3771, Val Acc: 0.2759
# Epoch 330/10000, Tr Loss: 1.2288, Tr Acc: 0.4876, Val Loss: 1.3770, Val Acc: 0.2759
# Epoch 331/10000, Tr Loss: 1.2378, Tr Acc: 0.5124, Val Loss: 1.3770, Val Acc: 0.2759
# Epoch 332/10000, Tr Loss: 1.2121, Tr Acc: 0.5124, Val Loss: 1.3769, Val Acc: 0.2759
# Epoch 333/10000, Tr Loss: 1.2172, Tr Acc: 0.4826, Val Loss: 1.3768, Val Acc: 0.2759
# Epoch 334/10000, Tr Loss: 1.2381, Tr Acc: 0.4826, Val Loss: 1.3768, Val Acc: 0.2759
# Epoch 335/10000, Tr Loss: 1.2005, Tr Acc: 0.5174, Val Loss: 1.3767, Val Acc: 0.2759
# Epoch 336/10000, Tr Loss: 1.2228, Tr Acc: 0.4776, Val Loss: 1.3766, Val Acc: 0.2759
# Epoch 337/10000, Tr Loss: 1.2262, Tr Acc: 0.5174, Val Loss: 1.3765, Val Acc: 0.2759
# Epoch 338/10000, Tr Loss: 1.2110, Tr Acc: 0.5373, Val Loss: 1.3764, Val Acc: 0.2644
# Epoch 339/10000, Tr Loss: 1.1812, Tr Acc: 0.6020, Val Loss: 1.3763, Val Acc: 0.2644
# Epoch 340/10000, Tr Loss: 1.2195, Tr Acc: 0.5124, Val Loss: 1.3763, Val Acc: 0.2644
# Epoch 341/10000, Tr Loss: 1.2048, Tr Acc: 0.5124, Val Loss: 1.3762, Val Acc: 0.2644
# Epoch 342/10000, Tr Loss: 1.1990, Tr Acc: 0.4975, Val Loss: 1.3761, Val Acc: 0.2644
# Epoch 343/10000, Tr Loss: 1.2350, Tr Acc: 0.4776, Val Loss: 1.3761, Val Acc: 0.2644
# Epoch 344/10000, Tr Loss: 1.2339, Tr Acc: 0.5174, Val Loss: 1.3760, Val Acc: 0.2759
# Epoch 345/10000, Tr Loss: 1.2259, Tr Acc: 0.4776, Val Loss: 1.3760, Val Acc: 0.2759
# Epoch 346/10000, Tr Loss: 1.2134, Tr Acc: 0.4279, Val Loss: 1.3759, Val Acc: 0.2759
# Epoch 347/10000, Tr Loss: 1.1961, Tr Acc: 0.5124, Val Loss: 1.3759, Val Acc: 0.2759
# Epoch 348/10000, Tr Loss: 1.2020, Tr Acc: 0.5721, Val Loss: 1.3759, Val Acc: 0.2759
# Epoch 349/10000, Tr Loss: 1.1941, Tr Acc: 0.4876, Val Loss: 1.3758, Val Acc: 0.2759
# Epoch 350/10000, Tr Loss: 1.1927, Tr Acc: 0.5572, Val Loss: 1.3758, Val Acc: 0.2874
# Epoch 351/10000, Tr Loss: 1.1689, Tr Acc: 0.6020, Val Loss: 1.3758, Val Acc: 0.2874
# Epoch 352/10000, Tr Loss: 1.1826, Tr Acc: 0.5373, Val Loss: 1.3758, Val Acc: 0.2874
# Epoch 353/10000, Tr Loss: 1.2366, Tr Acc: 0.4776, Val Loss: 1.3757, Val Acc: 0.2874
# Epoch 354/10000, Tr Loss: 1.2038, Tr Acc: 0.5274, Val Loss: 1.3756, Val Acc: 0.2874
# Epoch 355/10000, Tr Loss: 1.2153, Tr Acc: 0.4876, Val Loss: 1.3756, Val Acc: 0.2874
# Epoch 356/10000, Tr Loss: 1.2039, Tr Acc: 0.5274, Val Loss: 1.3756, Val Acc: 0.2874
# Epoch 357/10000, Tr Loss: 1.1646, Tr Acc: 0.5423, Val Loss: 1.3755, Val Acc: 0.2874
# Epoch 358/10000, Tr Loss: 1.1805, Tr Acc: 0.5522, Val Loss: 1.3755, Val Acc: 0.2874
# Epoch 359/10000, Tr Loss: 1.2001, Tr Acc: 0.5025, Val Loss: 1.3755, Val Acc: 0.2874
# Epoch 360/10000, Tr Loss: 1.2071, Tr Acc: 0.4876, Val Loss: 1.3754, Val Acc: 0.2874
# Epoch 361/10000, Tr Loss: 1.2015, Tr Acc: 0.5174, Val Loss: 1.3753, Val Acc: 0.2874
# Epoch 362/10000, Tr Loss: 1.1738, Tr Acc: 0.5473, Val Loss: 1.3753, Val Acc: 0.2874
# Epoch 363/10000, Tr Loss: 1.1719, Tr Acc: 0.5423, Val Loss: 1.3752, Val Acc: 0.2874
# Epoch 364/10000, Tr Loss: 1.2056, Tr Acc: 0.4925, Val Loss: 1.3751, Val Acc: 0.2874
# Epoch 365/10000, Tr Loss: 1.1920, Tr Acc: 0.5373, Val Loss: 1.3751, Val Acc: 0.2874
# Epoch 366/10000, Tr Loss: 1.1943, Tr Acc: 0.5274, Val Loss: 1.3750, Val Acc: 0.2874
# Epoch 367/10000, Tr Loss: 1.1923, Tr Acc: 0.5274, Val Loss: 1.3749, Val Acc: 0.2874
# Epoch 368/10000, Tr Loss: 1.2122, Tr Acc: 0.5224, Val Loss: 1.3749, Val Acc: 0.2874
# Epoch 369/10000, Tr Loss: 1.2010, Tr Acc: 0.4876, Val Loss: 1.3748, Val Acc: 0.2874
# Epoch 370/10000, Tr Loss: 1.1937, Tr Acc: 0.4925, Val Loss: 1.3748, Val Acc: 0.2874
# Epoch 371/10000, Tr Loss: 1.1770, Tr Acc: 0.5572, Val Loss: 1.3747, Val Acc: 0.2874
# Epoch 372/10000, Tr Loss: 1.1924, Tr Acc: 0.5423, Val Loss: 1.3746, Val Acc: 0.2874
# Epoch 373/10000, Tr Loss: 1.1834, Tr Acc: 0.5075, Val Loss: 1.3746, Val Acc: 0.2874
# Epoch 374/10000, Tr Loss: 1.1867, Tr Acc: 0.5572, Val Loss: 1.3745, Val Acc: 0.2874
# Epoch 375/10000, Tr Loss: 1.1659, Tr Acc: 0.5572, Val Loss: 1.3745, Val Acc: 0.2874
# Epoch 376/10000, Tr Loss: 1.1990, Tr Acc: 0.5075, Val Loss: 1.3744, Val Acc: 0.2874
# Epoch 377/10000, Tr Loss: 1.2042, Tr Acc: 0.5323, Val Loss: 1.3744, Val Acc: 0.2874
# Epoch 378/10000, Tr Loss: 1.2002, Tr Acc: 0.4826, Val Loss: 1.3743, Val Acc: 0.2874
# Epoch 379/10000, Tr Loss: 1.1747, Tr Acc: 0.5970, Val Loss: 1.3742, Val Acc: 0.2874
# Epoch 380/10000, Tr Loss: 1.1901, Tr Acc: 0.5423, Val Loss: 1.3742, Val Acc: 0.2874
# Epoch 381/10000, Tr Loss: 1.1932, Tr Acc: 0.5274, Val Loss: 1.3741, Val Acc: 0.2874
# Epoch 382/10000, Tr Loss: 1.1764, Tr Acc: 0.5423, Val Loss: 1.3740, Val Acc: 0.2874
# Epoch 383/10000, Tr Loss: 1.1511, Tr Acc: 0.6169, Val Loss: 1.3740, Val Acc: 0.2874
# Epoch 384/10000, Tr Loss: 1.1732, Tr Acc: 0.5373, Val Loss: 1.3739, Val Acc: 0.2874
# Epoch 385/10000, Tr Loss: 1.1730, Tr Acc: 0.5672, Val Loss: 1.3738, Val Acc: 0.2874
# Epoch 386/10000, Tr Loss: 1.1686, Tr Acc: 0.5373, Val Loss: 1.3737, Val Acc: 0.2874
# Epoch 387/10000, Tr Loss: 1.1648, Tr Acc: 0.5522, Val Loss: 1.3737, Val Acc: 0.2874
# Epoch 388/10000, Tr Loss: 1.1658, Tr Acc: 0.5821, Val Loss: 1.3736, Val Acc: 0.2874
# Epoch 389/10000, Tr Loss: 1.1865, Tr Acc: 0.5274, Val Loss: 1.3735, Val Acc: 0.2874
# Epoch 390/10000, Tr Loss: 1.1967, Tr Acc: 0.5721, Val Loss: 1.3735, Val Acc: 0.2759
# Epoch 391/10000, Tr Loss: 1.1483, Tr Acc: 0.5572, Val Loss: 1.3734, Val Acc: 0.2759
# Epoch 392/10000, Tr Loss: 1.1722, Tr Acc: 0.5423, Val Loss: 1.3733, Val Acc: 0.2759
# Epoch 393/10000, Tr Loss: 1.1849, Tr Acc: 0.5771, Val Loss: 1.3733, Val Acc: 0.2759
# Epoch 394/10000, Tr Loss: 1.1859, Tr Acc: 0.5473, Val Loss: 1.3732, Val Acc: 0.2759
# Epoch 395/10000, Tr Loss: 1.1903, Tr Acc: 0.5373, Val Loss: 1.3732, Val Acc: 0.2759
# Epoch 396/10000, Tr Loss: 1.1704, Tr Acc: 0.5721, Val Loss: 1.3732, Val Acc: 0.2759
# Epoch 397/10000, Tr Loss: 1.1825, Tr Acc: 0.5522, Val Loss: 1.3731, Val Acc: 0.2759
# Epoch 398/10000, Tr Loss: 1.1504, Tr Acc: 0.5871, Val Loss: 1.3731, Val Acc: 0.2644
# Epoch 399/10000, Tr Loss: 1.1744, Tr Acc: 0.5572, Val Loss: 1.3731, Val Acc: 0.2644
# Epoch 400/10000, Tr Loss: 1.2171, Tr Acc: 0.5473, Val Loss: 1.3731, Val Acc: 0.2644
# Epoch 401/10000, Tr Loss: 1.1986, Tr Acc: 0.5025, Val Loss: 1.3731, Val Acc: 0.2644
# Epoch 402/10000, Tr Loss: 1.1507, Tr Acc: 0.5771, Val Loss: 1.3730, Val Acc: 0.2644
# Epoch 403/10000, Tr Loss: 1.1446, Tr Acc: 0.6020, Val Loss: 1.3730, Val Acc: 0.2644
# Epoch 404/10000, Tr Loss: 1.1856, Tr Acc: 0.5373, Val Loss: 1.3730, Val Acc: 0.2644
# Epoch 405/10000, Tr Loss: 1.1443, Tr Acc: 0.6269, Val Loss: 1.3730, Val Acc: 0.2644
# Epoch 406/10000, Tr Loss: 1.1592, Tr Acc: 0.5871, Val Loss: 1.3729, Val Acc: 0.2644
# Epoch 407/10000, Tr Loss: 1.1966, Tr Acc: 0.5373, Val Loss: 1.3729, Val Acc: 0.2644
# Epoch 408/10000, Tr Loss: 1.1544, Tr Acc: 0.5920, Val Loss: 1.3729, Val Acc: 0.2644
# Epoch 409/10000, Tr Loss: 1.1952, Tr Acc: 0.5473, Val Loss: 1.3729, Val Acc: 0.2644
# Epoch 410/10000, Tr Loss: 1.1493, Tr Acc: 0.5821, Val Loss: 1.3728, Val Acc: 0.2644
# Epoch 411/10000, Tr Loss: 1.1594, Tr Acc: 0.5423, Val Loss: 1.3728, Val Acc: 0.2644
# Epoch 412/10000, Tr Loss: 1.1784, Tr Acc: 0.5124, Val Loss: 1.3727, Val Acc: 0.2644
# Epoch 413/10000, Tr Loss: 1.1611, Tr Acc: 0.5970, Val Loss: 1.3727, Val Acc: 0.2644
# Epoch 414/10000, Tr Loss: 1.1646, Tr Acc: 0.5323, Val Loss: 1.3726, Val Acc: 0.2644
# Epoch 415/10000, Tr Loss: 1.1754, Tr Acc: 0.5572, Val Loss: 1.3726, Val Acc: 0.2644
# Epoch 416/10000, Tr Loss: 1.1759, Tr Acc: 0.5572, Val Loss: 1.3725, Val Acc: 0.2644
# Epoch 417/10000, Tr Loss: 1.1377, Tr Acc: 0.6070, Val Loss: 1.3725, Val Acc: 0.2644
# Epoch 418/10000, Tr Loss: 1.1745, Tr Acc: 0.5721, Val Loss: 1.3724, Val Acc: 0.2644
# Epoch 419/10000, Tr Loss: 1.1603, Tr Acc: 0.5423, Val Loss: 1.3724, Val Acc: 0.2644
# Epoch 420/10000, Tr Loss: 1.1523, Tr Acc: 0.6020, Val Loss: 1.3724, Val Acc: 0.2644
# Epoch 421/10000, Tr Loss: 1.1251, Tr Acc: 0.5771, Val Loss: 1.3723, Val Acc: 0.2644
# Epoch 422/10000, Tr Loss: 1.1559, Tr Acc: 0.5920, Val Loss: 1.3723, Val Acc: 0.2644
# Epoch 423/10000, Tr Loss: 1.1725, Tr Acc: 0.5821, Val Loss: 1.3722, Val Acc: 0.2644
# Epoch 424/10000, Tr Loss: 1.1621, Tr Acc: 0.6070, Val Loss: 1.3722, Val Acc: 0.2644
# Epoch 425/10000, Tr Loss: 1.1661, Tr Acc: 0.5920, Val Loss: 1.3721, Val Acc: 0.2644
# Epoch 426/10000, Tr Loss: 1.1302, Tr Acc: 0.6219, Val Loss: 1.3721, Val Acc: 0.2644
# Epoch 427/10000, Tr Loss: 1.1386, Tr Acc: 0.6219, Val Loss: 1.3720, Val Acc: 0.2644
# Epoch 428/10000, Tr Loss: 1.2006, Tr Acc: 0.4925, Val Loss: 1.3720, Val Acc: 0.2644
# Epoch 429/10000, Tr Loss: 1.1370, Tr Acc: 0.6219, Val Loss: 1.3719, Val Acc: 0.2644
# Epoch 430/10000, Tr Loss: 1.1684, Tr Acc: 0.5672, Val Loss: 1.3719, Val Acc: 0.2644
# Epoch 431/10000, Tr Loss: 1.1638, Tr Acc: 0.5771, Val Loss: 1.3718, Val Acc: 0.2644
# Epoch 432/10000, Tr Loss: 1.1380, Tr Acc: 0.6070, Val Loss: 1.3718, Val Acc: 0.2644
# Epoch 433/10000, Tr Loss: 1.1296, Tr Acc: 0.6219, Val Loss: 1.3717, Val Acc: 0.2644
# Epoch 434/10000, Tr Loss: 1.1440, Tr Acc: 0.5871, Val Loss: 1.3717, Val Acc: 0.2644
# Epoch 435/10000, Tr Loss: 1.1469, Tr Acc: 0.6119, Val Loss: 1.3716, Val Acc: 0.2644
# Epoch 436/10000, Tr Loss: 1.1416, Tr Acc: 0.6070, Val Loss: 1.3716, Val Acc: 0.2644
# Epoch 437/10000, Tr Loss: 1.1376, Tr Acc: 0.5522, Val Loss: 1.3715, Val Acc: 0.2644
# Epoch 438/10000, Tr Loss: 1.1737, Tr Acc: 0.5174, Val Loss: 1.3715, Val Acc: 0.2644
# Epoch 439/10000, Tr Loss: 1.1616, Tr Acc: 0.5522, Val Loss: 1.3715, Val Acc: 0.2644
# Epoch 440/10000, Tr Loss: 1.1345, Tr Acc: 0.5871, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 441/10000, Tr Loss: 1.1458, Tr Acc: 0.5771, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 442/10000, Tr Loss: 1.1473, Tr Acc: 0.5821, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 443/10000, Tr Loss: 1.1274, Tr Acc: 0.6269, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 444/10000, Tr Loss: 1.1459, Tr Acc: 0.5771, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 445/10000, Tr Loss: 1.1123, Tr Acc: 0.6119, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 446/10000, Tr Loss: 1.1543, Tr Acc: 0.5622, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 447/10000, Tr Loss: 1.1488, Tr Acc: 0.5920, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 448/10000, Tr Loss: 1.1348, Tr Acc: 0.5920, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 449/10000, Tr Loss: 1.1494, Tr Acc: 0.5622, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 450/10000, Tr Loss: 1.1451, Tr Acc: 0.5522, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 451/10000, Tr Loss: 1.1564, Tr Acc: 0.5721, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 452/10000, Tr Loss: 1.1104, Tr Acc: 0.6119, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 453/10000, Tr Loss: 1.1568, Tr Acc: 0.5821, Val Loss: 1.3714, Val Acc: 0.2644
# Epoch 454/10000, Tr Loss: 1.0998, Tr Acc: 0.6517, Val Loss: 1.3713, Val Acc: 0.2644
# Epoch 455/10000, Tr Loss: 1.1480, Tr Acc: 0.6020, Val Loss: 1.3713, Val Acc: 0.2644
# Epoch 456/10000, Tr Loss: 1.1303, Tr Acc: 0.5871, Val Loss: 1.3713, Val Acc: 0.2644
# Epoch 457/10000, Tr Loss: 1.1265, Tr Acc: 0.6020, Val Loss: 1.3712, Val Acc: 0.2644
# Epoch 458/10000, Tr Loss: 1.1281, Tr Acc: 0.6766, Val Loss: 1.3712, Val Acc: 0.2644
# Epoch 459/10000, Tr Loss: 1.1002, Tr Acc: 0.6517, Val Loss: 1.3711, Val Acc: 0.2644
# Epoch 460/10000, Tr Loss: 1.1243, Tr Acc: 0.5672, Val Loss: 1.3711, Val Acc: 0.2644
# Epoch 461/10000, Tr Loss: 1.1302, Tr Acc: 0.5920, Val Loss: 1.3710, Val Acc: 0.2644
# Epoch 462/10000, Tr Loss: 1.1331, Tr Acc: 0.5821, Val Loss: 1.3710, Val Acc: 0.2644
# Epoch 463/10000, Tr Loss: 1.0945, Tr Acc: 0.6468, Val Loss: 1.3709, Val Acc: 0.2644
# Epoch 464/10000, Tr Loss: 1.1135, Tr Acc: 0.6070, Val Loss: 1.3709, Val Acc: 0.2644
# Epoch 465/10000, Tr Loss: 1.1218, Tr Acc: 0.5721, Val Loss: 1.3708, Val Acc: 0.2644
# Epoch 466/10000, Tr Loss: 1.1511, Tr Acc: 0.5721, Val Loss: 1.3707, Val Acc: 0.2644
# Epoch 467/10000, Tr Loss: 1.1515, Tr Acc: 0.5423, Val Loss: 1.3707, Val Acc: 0.2644
# Epoch 468/10000, Tr Loss: 1.1116, Tr Acc: 0.6517, Val Loss: 1.3707, Val Acc: 0.2644
# Epoch 469/10000, Tr Loss: 1.1110, Tr Acc: 0.6716, Val Loss: 1.3706, Val Acc: 0.2644
# Epoch 470/10000, Tr Loss: 1.1364, Tr Acc: 0.5970, Val Loss: 1.3705, Val Acc: 0.2644
# Epoch 471/10000, Tr Loss: 1.1236, Tr Acc: 0.6119, Val Loss: 1.3705, Val Acc: 0.2644
# Epoch 472/10000, Tr Loss: 1.1488, Tr Acc: 0.5920, Val Loss: 1.3705, Val Acc: 0.2644
# Epoch 473/10000, Tr Loss: 1.1316, Tr Acc: 0.5572, Val Loss: 1.3704, Val Acc: 0.2644
# Epoch 474/10000, Tr Loss: 1.1325, Tr Acc: 0.6169, Val Loss: 1.3704, Val Acc: 0.2644
# Epoch 475/10000, Tr Loss: 1.1140, Tr Acc: 0.6667, Val Loss: 1.3704, Val Acc: 0.2644
# Epoch 476/10000, Tr Loss: 1.0887, Tr Acc: 0.6517, Val Loss: 1.3703, Val Acc: 0.2644
# Epoch 477/10000, Tr Loss: 1.1426, Tr Acc: 0.5970, Val Loss: 1.3703, Val Acc: 0.2644
# Epoch 478/10000, Tr Loss: 1.1240, Tr Acc: 0.6020, Val Loss: 1.3703, Val Acc: 0.2644
# Epoch 479/10000, Tr Loss: 1.1392, Tr Acc: 0.5970, Val Loss: 1.3703, Val Acc: 0.2644
# Epoch 480/10000, Tr Loss: 1.1402, Tr Acc: 0.6020, Val Loss: 1.3702, Val Acc: 0.2644
# Epoch 481/10000, Tr Loss: 1.1337, Tr Acc: 0.5871, Val Loss: 1.3702, Val Acc: 0.2644
# Epoch 482/10000, Tr Loss: 1.0871, Tr Acc: 0.6915, Val Loss: 1.3701, Val Acc: 0.2644
# Epoch 483/10000, Tr Loss: 1.1303, Tr Acc: 0.5920, Val Loss: 1.3701, Val Acc: 0.2644
# Epoch 484/10000, Tr Loss: 1.1026, Tr Acc: 0.6219, Val Loss: 1.3701, Val Acc: 0.2644
# Epoch 485/10000, Tr Loss: 1.1149, Tr Acc: 0.6119, Val Loss: 1.3701, Val Acc: 0.2644
# Epoch 486/10000, Tr Loss: 1.1247, Tr Acc: 0.6119, Val Loss: 1.3700, Val Acc: 0.2644
# Epoch 487/10000, Tr Loss: 1.1063, Tr Acc: 0.6567, Val Loss: 1.3700, Val Acc: 0.2644
# Epoch 488/10000, Tr Loss: 1.1221, Tr Acc: 0.5522, Val Loss: 1.3700, Val Acc: 0.2644
# Epoch 489/10000, Tr Loss: 1.1377, Tr Acc: 0.5821, Val Loss: 1.3699, Val Acc: 0.2644
# Epoch 490/10000, Tr Loss: 1.0967, Tr Acc: 0.6567, Val Loss: 1.3699, Val Acc: 0.2644
# Epoch 491/10000, Tr Loss: 1.1008, Tr Acc: 0.6318, Val Loss: 1.3699, Val Acc: 0.2644
# Epoch 492/10000, Tr Loss: 1.1234, Tr Acc: 0.6468, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 493/10000, Tr Loss: 1.1064, Tr Acc: 0.6716, Val Loss: 1.3699, Val Acc: 0.2644
# Epoch 494/10000, Tr Loss: 1.0853, Tr Acc: 0.6716, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 495/10000, Tr Loss: 1.0848, Tr Acc: 0.6318, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 496/10000, Tr Loss: 1.0888, Tr Acc: 0.6318, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 497/10000, Tr Loss: 1.1116, Tr Acc: 0.5821, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 498/10000, Tr Loss: 1.1053, Tr Acc: 0.6269, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 499/10000, Tr Loss: 1.1031, Tr Acc: 0.6219, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 500/10000, Tr Loss: 1.1219, Tr Acc: 0.5771, Val Loss: 1.3698, Val Acc: 0.2644
# Epoch 501/10000, Tr Loss: 1.1030, Tr Acc: 0.6219, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 502/10000, Tr Loss: 1.1085, Tr Acc: 0.6169, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 503/10000, Tr Loss: 1.1214, Tr Acc: 0.6567, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 504/10000, Tr Loss: 1.1413, Tr Acc: 0.6070, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 505/10000, Tr Loss: 1.1164, Tr Acc: 0.6219, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 506/10000, Tr Loss: 1.1006, Tr Acc: 0.6070, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 507/10000, Tr Loss: 1.1042, Tr Acc: 0.6617, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 508/10000, Tr Loss: 1.1117, Tr Acc: 0.6468, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 509/10000, Tr Loss: 1.0727, Tr Acc: 0.6816, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 510/10000, Tr Loss: 1.1299, Tr Acc: 0.6219, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 511/10000, Tr Loss: 1.0904, Tr Acc: 0.6169, Val Loss: 1.3696, Val Acc: 0.2644
# Epoch 512/10000, Tr Loss: 1.1371, Tr Acc: 0.5672, Val Loss: 1.3696, Val Acc: 0.2644
# Epoch 513/10000, Tr Loss: 1.1302, Tr Acc: 0.6269, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 514/10000, Tr Loss: 1.1056, Tr Acc: 0.6567, Val Loss: 1.3697, Val Acc: 0.2644
# Epoch 515/10000, Tr Loss: 1.0842, Tr Acc: 0.6468, Val Loss: 1.3696, Val Acc: 0.2644
# Epoch 516/10000, Tr Loss: 1.0884, Tr Acc: 0.6119, Val Loss: 1.3696, Val Acc: 0.2759
# Epoch 517/10000, Tr Loss: 1.1184, Tr Acc: 0.6070, Val Loss: 1.3695, Val Acc: 0.2759
# Epoch 518/10000, Tr Loss: 1.1110, Tr Acc: 0.6219, Val Loss: 1.3694, Val Acc: 0.2759
# Epoch 519/10000, Tr Loss: 1.1179, Tr Acc: 0.5821, Val Loss: 1.3694, Val Acc: 0.2759
# Epoch 520/10000, Tr Loss: 1.1223, Tr Acc: 0.5473, Val Loss: 1.3694, Val Acc: 0.2759
# Epoch 521/10000, Tr Loss: 1.0959, Tr Acc: 0.6617, Val Loss: 1.3693, Val Acc: 0.2759
# Epoch 522/10000, Tr Loss: 1.0844, Tr Acc: 0.6667, Val Loss: 1.3693, Val Acc: 0.2759
# Epoch 523/10000, Tr Loss: 1.0658, Tr Acc: 0.6667, Val Loss: 1.3692, Val Acc: 0.2759
# Epoch 524/10000, Tr Loss: 1.0915, Tr Acc: 0.6517, Val Loss: 1.3691, Val Acc: 0.2759
# Epoch 525/10000, Tr Loss: 1.0742, Tr Acc: 0.6418, Val Loss: 1.3690, Val Acc: 0.2759
# Epoch 526/10000, Tr Loss: 1.1027, Tr Acc: 0.6318, Val Loss: 1.3690, Val Acc: 0.2874
# Epoch 527/10000, Tr Loss: 1.0751, Tr Acc: 0.6667, Val Loss: 1.3689, Val Acc: 0.2874
# Epoch 528/10000, Tr Loss: 1.1100, Tr Acc: 0.5970, Val Loss: 1.3689, Val Acc: 0.2874
# Epoch 529/10000, Tr Loss: 1.0853, Tr Acc: 0.6468, Val Loss: 1.3688, Val Acc: 0.2874
# Epoch 530/10000, Tr Loss: 1.1062, Tr Acc: 0.6766, Val Loss: 1.3688, Val Acc: 0.2874
# Epoch 531/10000, Tr Loss: 1.1029, Tr Acc: 0.6119, Val Loss: 1.3688, Val Acc: 0.2874
# Epoch 532/10000, Tr Loss: 1.0819, Tr Acc: 0.6269, Val Loss: 1.3687, Val Acc: 0.2874
# Epoch 533/10000, Tr Loss: 1.0974, Tr Acc: 0.6269, Val Loss: 1.3687, Val Acc: 0.2874
# Epoch 534/10000, Tr Loss: 1.0911, Tr Acc: 0.6816, Val Loss: 1.3686, Val Acc: 0.2874
# Epoch 535/10000, Tr Loss: 1.1093, Tr Acc: 0.6219, Val Loss: 1.3686, Val Acc: 0.2874
# Epoch 536/10000, Tr Loss: 1.0668, Tr Acc: 0.6368, Val Loss: 1.3685, Val Acc: 0.2874
# Epoch 537/10000, Tr Loss: 1.0508, Tr Acc: 0.7015, Val Loss: 1.3685, Val Acc: 0.2874
# Epoch 538/10000, Tr Loss: 1.0861, Tr Acc: 0.6468, Val Loss: 1.3685, Val Acc: 0.2874
# Epoch 539/10000, Tr Loss: 1.0761, Tr Acc: 0.6816, Val Loss: 1.3685, Val Acc: 0.2874
# Epoch 540/10000, Tr Loss: 1.0896, Tr Acc: 0.6617, Val Loss: 1.3684, Val Acc: 0.2874
# Epoch 541/10000, Tr Loss: 1.1367, Tr Acc: 0.5522, Val Loss: 1.3684, Val Acc: 0.2874
# Epoch 542/10000, Tr Loss: 1.0773, Tr Acc: 0.6269, Val Loss: 1.3684, Val Acc: 0.2874
# Epoch 543/10000, Tr Loss: 1.0990, Tr Acc: 0.6617, Val Loss: 1.3684, Val Acc: 0.2874
# Epoch 544/10000, Tr Loss: 1.0881, Tr Acc: 0.6517, Val Loss: 1.3683, Val Acc: 0.2874
# Epoch 545/10000, Tr Loss: 1.0628, Tr Acc: 0.6915, Val Loss: 1.3683, Val Acc: 0.2874
# Epoch 546/10000, Tr Loss: 1.0774, Tr Acc: 0.6716, Val Loss: 1.3683, Val Acc: 0.2874
# Epoch 547/10000, Tr Loss: 1.1110, Tr Acc: 0.6368, Val Loss: 1.3683, Val Acc: 0.2759
# Epoch 548/10000, Tr Loss: 1.0602, Tr Acc: 0.6716, Val Loss: 1.3683, Val Acc: 0.2759
# Epoch 549/10000, Tr Loss: 1.0422, Tr Acc: 0.7164, Val Loss: 1.3683, Val Acc: 0.2759
# Epoch 550/10000, Tr Loss: 1.0651, Tr Acc: 0.6567, Val Loss: 1.3683, Val Acc: 0.2759
# Epoch 551/10000, Tr Loss: 1.0759, Tr Acc: 0.6418, Val Loss: 1.3684, Val Acc: 0.2759
# Epoch 552/10000, Tr Loss: 1.0787, Tr Acc: 0.6468, Val Loss: 1.3684, Val Acc: 0.2759
# ...
# Epoch 8017/10000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 2.8908, Val Acc: 0.3103
# Epoch 8018/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8912, Val Acc: 0.3103
# Epoch 8019/10000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 2.8915, Val Acc: 0.3103
# Epoch 8020/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.8916, Val Acc: 0.3103
# Epoch 8021/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.8917, Val Acc: 0.3103
# Epoch 8022/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8914, Val Acc: 0.3103
# Epoch 8023/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.8919, Val Acc: 0.3103
# Epoch 8024/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.8916, Val Acc: 0.3103
# Epoch 8025/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8920, Val Acc: 0.3103
# Epoch 8026/10000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 2.8924, Val Acc: 0.3103
# Epoch 8027/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.8929, Val Acc: 0.3103
# Epoch 8028/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.8929, Val Acc: 0.3103
# Epoch 8029/10000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 2.8932, Val Acc: 0.3103
# Epoch 8030/10000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 2.8932, Val Acc: 0.3103
# Epoch 8031/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8938, Val Acc: 0.3103
# Epoch 8032/10000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 2.8940, Val Acc: 0.3103
# Epoch 8033/10000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 2.8943, Val Acc: 0.3103
# Epoch 8034/10000, Tr Loss: 0.0087, Tr Acc: 1.0000, Val Loss: 2.8944, Val Acc: 0.3103
# Epoch 8035/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.8946, Val Acc: 0.3103
# Epoch 8036/10000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 2.8950, Val Acc: 0.3103
# Epoch 8037/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.8955, Val Acc: 0.3103
# Epoch 8038/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.8960, Val Acc: 0.3103
# Epoch 8039/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.8960, Val Acc: 0.3103
# Epoch 8040/10000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 2.8960, Val Acc: 0.3103
# Epoch 8041/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.8959, Val Acc: 0.3103
# Epoch 8042/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.8960, Val Acc: 0.3103
# Epoch 8043/10000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 2.8965, Val Acc: 0.3103
# Epoch 8044/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8969, Val Acc: 0.3103
# Epoch 8045/10000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 2.8975, Val Acc: 0.3103
# Epoch 8046/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.8973, Val Acc: 0.3103
# Epoch 8047/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.8973, Val Acc: 0.3103
# Epoch 8048/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8973, Val Acc: 0.3103
# Epoch 8049/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.8969, Val Acc: 0.3103
# Epoch 8050/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.8967, Val Acc: 0.3103
# Epoch 8051/10000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 2.8964, Val Acc: 0.3103
# Epoch 8052/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8969, Val Acc: 0.3103
# Epoch 8053/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8964, Val Acc: 0.3103
# Epoch 8054/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8971, Val Acc: 0.3103
# Epoch 8055/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.8967, Val Acc: 0.3103
# Epoch 8056/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8969, Val Acc: 0.3103
# Epoch 8057/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8972, Val Acc: 0.3103
# Epoch 8058/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.8971, Val Acc: 0.3103
# Epoch 8059/10000, Tr Loss: 0.0087, Tr Acc: 1.0000, Val Loss: 2.8970, Val Acc: 0.3103
# Epoch 8060/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.8973, Val Acc: 0.3103
# Epoch 8061/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8968, Val Acc: 0.3103
# Epoch 8062/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8966, Val Acc: 0.3103
# Epoch 8063/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.8969, Val Acc: 0.3103
# Epoch 8064/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8972, Val Acc: 0.3103
# Epoch 8065/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.8974, Val Acc: 0.3103
# Epoch 8066/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.8978, Val Acc: 0.3103
# Epoch 8067/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.8977, Val Acc: 0.3103
# Epoch 8068/10000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 2.8982, Val Acc: 0.3103
# Epoch 8069/10000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 2.8984, Val Acc: 0.3103
# Epoch 8070/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.8989, Val Acc: 0.3103
# Epoch 8071/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.8990, Val Acc: 0.3103
# Epoch 8072/10000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 2.8987, Val Acc: 0.3103
# Epoch 8073/10000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 2.8988, Val Acc: 0.3103
# Epoch 8074/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.8986, Val Acc: 0.3103
# Epoch 8075/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.8989, Val Acc: 0.3103
# Epoch 8076/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.8991, Val Acc: 0.3103
# Epoch 8077/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.8996, Val Acc: 0.3103
# Epoch 8078/10000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 2.9004, Val Acc: 0.3103
# Epoch 8079/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9009, Val Acc: 0.3103
# Epoch 8080/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9013, Val Acc: 0.3103
# Epoch 8081/10000, Tr Loss: 0.0082, Tr Acc: 1.0000, Val Loss: 2.9016, Val Acc: 0.3103
# Epoch 8082/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.9019, Val Acc: 0.3103
# Epoch 8083/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9025, Val Acc: 0.3103
# Epoch 8084/10000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 2.9025, Val Acc: 0.3103
# Epoch 8085/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9031, Val Acc: 0.3103
# Epoch 8086/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9032, Val Acc: 0.3103
# Epoch 8087/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9029, Val Acc: 0.3103
# Epoch 8088/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9032, Val Acc: 0.3103
# Epoch 8089/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.9034, Val Acc: 0.3103
# Epoch 8090/10000, Tr Loss: 0.0065, Tr Acc: 1.0000, Val Loss: 2.9035, Val Acc: 0.3103
# Epoch 8091/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.9042, Val Acc: 0.3103
# Epoch 8092/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.9041, Val Acc: 0.3103
# Epoch 8093/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9038, Val Acc: 0.3103
# Epoch 8094/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9039, Val Acc: 0.3103
# Epoch 8095/10000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 2.9040, Val Acc: 0.3103
# Epoch 8096/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.9039, Val Acc: 0.3103
# Epoch 8097/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9043, Val Acc: 0.3103
# Epoch 8098/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9048, Val Acc: 0.3103
# Epoch 8099/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.9050, Val Acc: 0.3103
# Epoch 8100/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9054, Val Acc: 0.3103
# Epoch 8101/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9059, Val Acc: 0.3103
# Epoch 8102/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9062, Val Acc: 0.3103
# Epoch 8103/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9068, Val Acc: 0.3103
# Epoch 8104/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.9075, Val Acc: 0.3103
# Epoch 8105/10000, Tr Loss: 0.0088, Tr Acc: 1.0000, Val Loss: 2.9076, Val Acc: 0.3103
# Epoch 8106/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9076, Val Acc: 0.3103
# Epoch 8107/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9080, Val Acc: 0.3103
# Epoch 8108/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9084, Val Acc: 0.3103
# Epoch 8109/10000, Tr Loss: 0.0081, Tr Acc: 1.0000, Val Loss: 2.9086, Val Acc: 0.3103
# Epoch 8110/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9090, Val Acc: 0.3103
# Epoch 8111/10000, Tr Loss: 0.0083, Tr Acc: 1.0000, Val Loss: 2.9091, Val Acc: 0.3103
# Epoch 8112/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9095, Val Acc: 0.3103
# Epoch 8113/10000, Tr Loss: 0.0086, Tr Acc: 1.0000, Val Loss: 2.9097, Val Acc: 0.3103
# Epoch 8114/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.9101, Val Acc: 0.3103
# Epoch 8115/10000, Tr Loss: 0.0067, Tr Acc: 1.0000, Val Loss: 2.9099, Val Acc: 0.3103
# Epoch 8116/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.9104, Val Acc: 0.3103
# Epoch 8117/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9104, Val Acc: 0.3103
# Epoch 8118/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9108, Val Acc: 0.3103
# Epoch 8119/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9108, Val Acc: 0.3103
# Epoch 8120/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9108, Val Acc: 0.3103
# Epoch 8121/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9114, Val Acc: 0.3103
# Epoch 8122/10000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 2.9111, Val Acc: 0.3103
# Epoch 8123/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9112, Val Acc: 0.3103
# Epoch 8124/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9114, Val Acc: 0.3103
# Epoch 8125/10000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 2.9110, Val Acc: 0.3103
# Epoch 8126/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9112, Val Acc: 0.3103
# Epoch 8127/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.9107, Val Acc: 0.3103
# Epoch 8128/10000, Tr Loss: 0.0067, Tr Acc: 1.0000, Val Loss: 2.9103, Val Acc: 0.3103
# Epoch 8129/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9099, Val Acc: 0.3103
# Epoch 8130/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9102, Val Acc: 0.3103
# Epoch 8131/10000, Tr Loss: 0.0067, Tr Acc: 1.0000, Val Loss: 2.9107, Val Acc: 0.3103
# Epoch 8132/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9105, Val Acc: 0.3103
# Epoch 8133/10000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 2.9104, Val Acc: 0.3103
# Epoch 8134/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.9106, Val Acc: 0.3103
# Epoch 8135/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9110, Val Acc: 0.3103
# Epoch 8136/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9113, Val Acc: 0.3103
# Epoch 8137/10000, Tr Loss: 0.0066, Tr Acc: 1.0000, Val Loss: 2.9110, Val Acc: 0.3103
# Epoch 8138/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9109, Val Acc: 0.3103
# Epoch 8139/10000, Tr Loss: 0.0084, Tr Acc: 1.0000, Val Loss: 2.9108, Val Acc: 0.3103
# Epoch 8140/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.9109, Val Acc: 0.3103
# Epoch 8141/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.9105, Val Acc: 0.3103
# Epoch 8142/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9105, Val Acc: 0.3103
# Epoch 8143/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9101, Val Acc: 0.3103
# Epoch 8144/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.9101, Val Acc: 0.3103
# Epoch 8145/10000, Tr Loss: 0.0068, Tr Acc: 1.0000, Val Loss: 2.9104, Val Acc: 0.3103
# Epoch 8146/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9108, Val Acc: 0.3103
# Epoch 8147/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9111, Val Acc: 0.3103
# Epoch 8148/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9117, Val Acc: 0.3103
# Epoch 8149/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9123, Val Acc: 0.3103
# Epoch 8150/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9131, Val Acc: 0.3103
# Epoch 8151/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9135, Val Acc: 0.3103
# Epoch 8152/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9138, Val Acc: 0.3103
# Epoch 8153/10000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 2.9142, Val Acc: 0.3103
# Epoch 8154/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9148, Val Acc: 0.3103
# Epoch 8155/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.9153, Val Acc: 0.3103
# Epoch 8156/10000, Tr Loss: 0.0080, Tr Acc: 1.0000, Val Loss: 2.9160, Val Acc: 0.3103
# Epoch 8157/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9163, Val Acc: 0.3103
# Epoch 8158/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.9164, Val Acc: 0.3103
# Epoch 8159/10000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 2.9171, Val Acc: 0.3103
# Epoch 8160/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9175, Val Acc: 0.3103
# Epoch 8161/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9177, Val Acc: 0.3103
# Epoch 8162/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9180, Val Acc: 0.3103
# Epoch 8163/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9177, Val Acc: 0.3103
# Epoch 8164/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9185, Val Acc: 0.3103
# Epoch 8165/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9190, Val Acc: 0.3103
# Epoch 8166/10000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 2.9191, Val Acc: 0.3103
# Epoch 8167/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9191, Val Acc: 0.3103
# Epoch 8168/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9197, Val Acc: 0.3103
# Epoch 8169/10000, Tr Loss: 0.0077, Tr Acc: 1.0000, Val Loss: 2.9201, Val Acc: 0.3103
# Epoch 8170/10000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 2.9198, Val Acc: 0.3103
# Epoch 8171/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9199, Val Acc: 0.3103
# Epoch 8172/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9203, Val Acc: 0.3103
# Epoch 8173/10000, Tr Loss: 0.0085, Tr Acc: 1.0000, Val Loss: 2.9206, Val Acc: 0.3103
# Epoch 8174/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9210, Val Acc: 0.3103
# Epoch 8175/10000, Tr Loss: 0.0069, Tr Acc: 1.0000, Val Loss: 2.9214, Val Acc: 0.3103
# Epoch 8176/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9221, Val Acc: 0.3103
# Epoch 8177/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9221, Val Acc: 0.3103
# Epoch 8178/10000, Tr Loss: 0.0076, Tr Acc: 1.0000, Val Loss: 2.9225, Val Acc: 0.3103
# Epoch 8179/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9227, Val Acc: 0.3103
# Epoch 8180/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9230, Val Acc: 0.3103
# Epoch 8181/10000, Tr Loss: 0.0065, Tr Acc: 1.0000, Val Loss: 2.9233, Val Acc: 0.3103
# Epoch 8182/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9234, Val Acc: 0.3103
# Epoch 8183/10000, Tr Loss: 0.0066, Tr Acc: 1.0000, Val Loss: 2.9243, Val Acc: 0.3103
# Epoch 8184/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9249, Val Acc: 0.3103
# Epoch 8185/10000, Tr Loss: 0.0067, Tr Acc: 1.0000, Val Loss: 2.9247, Val Acc: 0.3103
# Epoch 8186/10000, Tr Loss: 0.0063, Tr Acc: 1.0000, Val Loss: 2.9250, Val Acc: 0.3103
# Epoch 8187/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9250, Val Acc: 0.3103
# Epoch 8188/10000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 2.9245, Val Acc: 0.3103
# Epoch 8189/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9243, Val Acc: 0.3103
# Epoch 8190/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9241, Val Acc: 0.3103
# Epoch 8191/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9242, Val Acc: 0.3103
# Epoch 8192/10000, Tr Loss: 0.0074, Tr Acc: 1.0000, Val Loss: 2.9241, Val Acc: 0.3103
# Epoch 8193/10000, Tr Loss: 0.0070, Tr Acc: 1.0000, Val Loss: 2.9237, Val Acc: 0.3103
# Epoch 8194/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9233, Val Acc: 0.3103
# Epoch 8195/10000, Tr Loss: 0.0066, Tr Acc: 1.0000, Val Loss: 2.9232, Val Acc: 0.3103
# Epoch 8196/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9232, Val Acc: 0.3103
# Epoch 8197/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9235, Val Acc: 0.3103
# Epoch 8198/10000, Tr Loss: 0.0078, Tr Acc: 1.0000, Val Loss: 2.9229, Val Acc: 0.3103
# Epoch 8199/10000, Tr Loss: 0.0073, Tr Acc: 1.0000, Val Loss: 2.9231, Val Acc: 0.3103
# Epoch 8200/10000, Tr Loss: 0.0072, Tr Acc: 1.0000, Val Loss: 2.9233, Val Acc: 0.3103
# Epoch 8201/10000, Tr Loss: 0.0079, Tr Acc: 1.0000, Val Loss: 2.9229, Val Acc: 0.3103
# Epoch 8202/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9230, Val Acc: 0.3103
# Epoch 8203/10000, Tr Loss: 0.0075, Tr Acc: 1.0000, Val Loss: 2.9232, Val Acc: 0.3103
# Epoch 8204/10000, Tr Loss: 0.0071, Tr Acc: 1.0000, Val Loss: 2.9234, Val Acc: 0.3103
